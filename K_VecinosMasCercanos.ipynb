# %% [markdown]
# ##Técnica de los K Vecinos más Cercanos

# %%
import time
import pandas as pd
from itertools import combinations
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, max_error, r2_score

# Cargar datos desde el archivo CSV
df_datos = pd.read_csv("datos/insurance.csv")

# Codificación One Hot para la columna 'region'
codificador_one_hot = OneHotEncoder(sparse=False)
codificacion_one_hot = codificador_one_hot.fit_transform(df_datos[['region']])
arr_nombre_nuevas_columnas = ['region_' + str(cat) for cat in codificador_one_hot.categories_[0]]
df_nuevas_columnas_one_hot = pd.DataFrame(codificacion_one_hot, columns=arr_nombre_nuevas_columnas)
df_datos = pd.concat([df_datos, df_nuevas_columnas_one_hot], axis=1)

# Columnas incluyendo 'region'
columnas_especificas = ['age', 'bmi'] + arr_nombre_nuevas_columnas + ['children', 'sex']

# Crear conjuntos de datos de entrenamiento y prueba para las columnas seleccionadas
df_X = pd.DataFrame(df_datos, columns=columnas_especificas)
df_y = pd.DataFrame(df_datos, columns=['charges'])
df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(df_X, df_y, test_size=0.2, random_state=100)

# Llenar valores faltantes con SimpleImputer
imputer = SimpleImputer(strategy='mean')

df_X_train_filled = pd.DataFrame(imputer.fit_transform(df_X_train), columns=df_X_train.columns)
df_X_test_filled = pd.DataFrame(imputer.transform(df_X_test), columns=df_X_test.columns)

# Normalizar variables independientes usando MinMaxScaler
scaler_X = MinMaxScaler()
df_X_train_scaled = pd.DataFrame(scaler_X.fit_transform(df_X_train_filled), columns=df_X_train_filled.columns)
df_X_test_scaled = pd.DataFrame(scaler_X.transform(df_X_test_filled), columns=df_X_test_filled.columns)

# Normalizar variable dependiente usando MinMaxScaler
scaler_y = MinMaxScaler()
df_y_train_scaled = pd.DataFrame(scaler_y.fit_transform(df_y_train), columns=df_y_train.columns)
df_y_test_scaled = pd.DataFrame(scaler_y.transform(df_y_test), columns=df_y_test.columns)

# Lista para almacenar los resultados
resultados_knn = []

# Valores de k para KNN
valores_k = [1, 2, 3]

# Iterar sobre los valores de k
for k in valores_k:
    # Generar todas las combinaciones posibles de columnas
    for i in range(1, len(columnas_especificas) + 1):
        combinaciones_columnas = combinations(columnas_especificas, i)
        for combo in combinaciones_columnas:
            # Convertir la combinación en una lista para poder seleccionar las columnas del DataFrame
            combo_lista = list(combo)
            # Crear y entrenar el modelo de regresión KNN
            model = KNeighborsRegressor(n_neighbors=k)
            model.fit(df_X_train_scaled[combo_lista], df_y_train_scaled.values.ravel())
            # Predicciones
            arr_y_test_predicho_scaled = model.predict(df_X_test_scaled[combo_lista])

            # Desnormalizar las predicciones usando el escalador de datos de prueba
            arr_y_test_predicho_desnormalizado = scaler_y.inverse_transform(arr_y_test_predicho_scaled.reshape(-1, 1)).flatten()

            # Desnormalizar los datos de prueba y entrenamiento
            df_y_test_desnormalizado = scaler_y.inverse_transform(df_y_test_scaled.values).flatten()
            # Desnormalizar los datos de prueba y entrenamiento
            df_X_test_desnormalizado = pd.DataFrame(scaler_X.inverse_transform(df_X_test_scaled), columns=df_X_test_scaled.columns)
            df_X_test_desnormalizado = df_X_test_desnormalizado.loc[:, combo_lista]
            
            # Métricas de evaluación del modelo
            max_ea = max_error(df_y_test_desnormalizado, arr_y_test_predicho_desnormalizado)
            mae = mean_absolute_error(df_y_test_desnormalizado, arr_y_test_predicho_desnormalizado)
            mse = mean_squared_error(df_y_test_desnormalizado, arr_y_test_predicho_desnormalizado)
            r2 = r2_score(df_y_test_desnormalizado, arr_y_test_predicho_desnormalizado)

            # Almacenar resultados en la lista
            resultados_knn.append({
                'Valor_K': k,
                'Columnas': combo_lista,
                'Máximo_EA': max_ea,
                'EA_Medio': mae,
                'R^2': r2
            })

# Crear un DataFrame a partir de la lista de resultados
df_resultados_knn = pd.DataFrame(resultados_knn)

# Imprimir resultados
for idx, row in df_resultados_knn.iterrows():
    print(f"Resultados para K={row['Valor_K']} y Columnas={row['Columnas']}:")
    print(f"   Máximo EA: {row['Máximo_EA']:.2f}")
    print(f"   EA Medio: {row['EA_Medio']:.2f}")
    print(f"   R^2: {row['R^2']:.4f}")
    print("-" * 90)
# Out:
# C:\Users\rimel\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Resultados para K=1 y Columnas=['age']:
#    Máximo EA: 55310.88
#    EA Medio: 10365.32
#    R^2: -0.7796
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi']:
#    Máximo EA: 56999.59
#    EA Medio: 12197.21
#    R^2: -0.8657
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast']:
#    Máximo EA: 55301.66
#    EA Medio: 10141.43
#    R^2: -0.4142
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest']:
#    Máximo EA: 49906.39
#    EA Medio: 10014.97
#    R^2: -0.0392
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast']:
#    Máximo EA: 43906.09
#    EA Medio: 10299.26
#    R^2: -0.1579
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southwest']:
#    Máximo EA: 43906.09
#    EA Medio: 9756.12
#    R^2: -0.0418
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['children']:
#    Máximo EA: 49906.39
#    EA Medio: 9402.50
#    R^2: -0.1127
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex']:
#    Máximo EA: 42455.77
#    EA Medio: 13694.58
#    R^2: -0.5669
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi']:
#    Máximo EA: 55151.82
#    EA Medio: 9821.04
#    R^2: -0.6323
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast']:
#    Máximo EA: 51771.62
#    EA Medio: 10248.55
#    R^2: -0.7113
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest']:
#    Máximo EA: 55310.88
#    EA Medio: 9798.52
#    R^2: -0.5433
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southeast']:
#    Máximo EA: 55310.88
#    EA Medio: 10722.48
#    R^2: -0.7643
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southwest']:
#    Máximo EA: 54327.48
#    EA Medio: 9617.31
#    R^2: -0.5981
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children']:
#    Máximo EA: 54331.18
#    EA Medio: 11370.82
#    R^2: -0.9762
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex']:
#    Máximo EA: 53636.37
#    EA Medio: 10391.19
#    R^2: -0.6761
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast']:
#    Máximo EA: 56999.59
#    EA Medio: 12462.49
#    R^2: -0.9398
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12098.66
#    R^2: -0.8792
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southeast']:
#    Máximo EA: 56999.59
#    EA Medio: 12189.53
#    R^2: -0.8926
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12263.91
#    R^2: -0.8788
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'children']:
#    Máximo EA: 52389.10
#    EA Medio: 11641.86
#    R^2: -0.7782
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'sex']:
#    Máximo EA: 47823.45
#    EA Medio: 12205.72
#    R^2: -0.7751
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest']:
#    Máximo EA: 49906.39
#    EA Medio: 10370.44
#    R^2: -0.0657
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southeast']:
#    Máximo EA: 47789.79
#    EA Medio: 9498.15
#    R^2: -0.1471
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southwest']:
#    Máximo EA: 55301.66
#    EA Medio: 9843.95
#    R^2: -0.3217
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 10698.35
#    R^2: -0.6525
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'sex']:
#    Máximo EA: 55274.35
#    EA Medio: 11076.36
#    R^2: -0.4951
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southeast']:
#    Máximo EA: 49906.39
#    EA Medio: 9953.11
#    R^2: -0.1710
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southwest']:
#    Máximo EA: 49906.39
#    EA Medio: 9409.97
#    R^2: -0.0549
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 10507.89
#    R^2: -0.3499
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'sex']:
#    Máximo EA: 55126.65
#    EA Medio: 10573.99
#    R^2: -0.4421
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast', 'region_southwest']:
#    Máximo EA: 44770.89
#    EA Medio: 10334.93
#    R^2: -0.3287
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast', 'children']:
#    Máximo EA: 55629.75
#    EA Medio: 14771.61
#    R^2: -1.3408
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast', 'sex']:
#    Máximo EA: 45757.75
#    EA Medio: 15913.08
#    R^2: -1.4368
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southwest', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 9550.73
#    R^2: -0.2260
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southwest', 'sex']:
#    Máximo EA: 43327.38
#    EA Medio: 12768.49
#    R^2: -0.5789
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['children', 'sex']:
#    Máximo EA: 49699.92
#    EA Medio: 11580.15
#    R^2: -0.3882
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast']:
#    Máximo EA: 55151.82
#    EA Medio: 10197.05
#    R^2: -0.7389
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest']:
#    Máximo EA: 55151.82
#    EA Medio: 9404.44
#    R^2: -0.5515
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southeast']:
#    Máximo EA: 53142.35
#    EA Medio: 10555.66
#    R^2: -0.7637
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southwest']:
#    Máximo EA: 54107.87
#    EA Medio: 9514.31
#    R^2: -0.5634
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10619.10
#    R^2: -0.7781
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'sex']:
#    Máximo EA: 55151.82
#    EA Medio: 9889.39
#    R^2: -0.5870
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest']:
#    Máximo EA: 51771.62
#    EA Medio: 10305.18
#    R^2: -0.6882
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southeast']:
#    Máximo EA: 51771.62
#    EA Medio: 9829.79
#    R^2: -0.6308
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southwest']:
#    Máximo EA: 51771.62
#    EA Medio: 8666.03
#    R^2: -0.2886
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 9518.13
#    R^2: -0.5824
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'sex']:
#    Máximo EA: 54224.05
#    EA Medio: 10309.85
#    R^2: -0.7712
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southeast']:
#    Máximo EA: 55310.88
#    EA Medio: 9808.76
#    R^2: -0.5582
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southwest']:
#    Máximo EA: 54695.34
#    EA Medio: 9729.16
#    R^2: -0.5439
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'children']:
#    Máximo EA: 54695.34
#    EA Medio: 11284.89
#    R^2: -0.9297
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'sex']:
#    Máximo EA: 54809.78
#    EA Medio: 10532.54
#    R^2: -0.7815
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southeast', 'region_southwest']:
#    Máximo EA: 54331.18
#    EA Medio: 10385.83
#    R^2: -0.6643
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southeast', 'children']:
#    Máximo EA: 54331.18
#    EA Medio: 11325.53
#    R^2: -0.9094
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southeast', 'sex']:
#    Máximo EA: 53987.51
#    EA Medio: 11311.83
#    R^2: -0.9726
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southwest', 'children']:
#    Máximo EA: 54331.18
#    EA Medio: 9965.14
#    R^2: -0.5997
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southwest', 'sex']:
#    Máximo EA: 53243.67
#    EA Medio: 10117.70
#    R^2: -0.5847
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'sex']:
#    Máximo EA: 53832.81
#    EA Medio: 9847.54
#    R^2: -0.6421
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12864.58
#    R^2: -1.0375
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_southeast']:
#    Máximo EA: 56999.59
#    EA Medio: 12231.54
#    R^2: -0.9008
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_southwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12342.79
#    R^2: -0.8859
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 11296.70
#    R^2: -0.7107
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'sex']:
#    Máximo EA: 47823.45
#    EA Medio: 12501.14
#    R^2: -0.9538
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'region_southeast']:
#    Máximo EA: 56999.59
#    EA Medio: 12420.17
#    R^2: -0.9074
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'region_southwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12875.99
#    R^2: -1.0576
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'children']:
#    Máximo EA: 52389.10
#    EA Medio: 10939.10
#    R^2: -0.6143
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'sex']:
#    Máximo EA: 48277.46
#    EA Medio: 12037.24
#    R^2: -0.8005
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southeast', 'region_southwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12856.27
#    R^2: -1.0259
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southeast', 'children']:
#    Máximo EA: 53808.75
#    EA Medio: 11181.84
#    R^2: -0.6731
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southeast', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 12778.74
#    R^2: -0.9605
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southwest', 'children']:
#    Máximo EA: 59850.93
#    EA Medio: 11685.24
#    R^2: -0.8619
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southwest', 'sex']:
#    Máximo EA: 49427.17
#    EA Medio: 12028.76
#    R^2: -0.8089
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'children', 'sex']:
#    Máximo EA: 54087.02
#    EA Medio: 11813.60
#    R^2: -0.7769
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'region_southeast']:
#    Máximo EA: 49906.39
#    EA Medio: 9988.78
#    R^2: -0.3418
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'region_southwest']:
#    Máximo EA: 49906.39
#    EA Medio: 9233.80
#    R^2: -0.0529
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 10596.01
#    R^2: -0.5815
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'sex']:
#    Máximo EA: 55126.65
#    EA Medio: 10863.70
#    R^2: -0.5064
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southeast', 'region_southwest']:
#    Máximo EA: 55301.66
#    EA Medio: 9693.29
#    R^2: -0.2862
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southeast', 'children']:
#    Máximo EA: 47773.74
#    EA Medio: 12239.63
#    R^2: -0.7149
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southeast', 'sex']:
#    Máximo EA: 57117.31
#    EA Medio: 11517.17
#    R^2: -0.6676
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southwest', 'children']:
#    Máximo EA: 47773.74
#    EA Medio: 10040.78
#    R^2: -0.3243
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southwest', 'sex']:
#    Máximo EA: 55274.35
#    EA Medio: 11311.36
#    R^2: -0.6309
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'children', 'sex']:
#    Máximo EA: 47773.74
#    EA Medio: 10918.52
#    R^2: -0.5407
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 49906.39
#    EA Medio: 9348.10
#    R^2: -0.1867
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 55666.99
#    EA Medio: 13482.60
#    R^2: -1.2329
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 55126.65
#    EA Medio: 11620.26
#    R^2: -0.4677
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 9662.94
#    R^2: -0.1858
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 55126.65
#    EA Medio: 11875.84
#    R^2: -0.5566
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'children', 'sex']:
#    Máximo EA: 46538.75
#    EA Medio: 9937.71
#    R^2: -0.2794
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 13364.94
#    R^2: -1.1174
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 52573.00
#    EA Medio: 13073.33
#    R^2: -1.2371
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast', 'children', 'sex']:
#    Máximo EA: 56239.56
#    EA Medio: 13375.81
#    R^2: -1.0905
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southwest', 'children', 'sex']:
#    Máximo EA: 54233.34
#    EA Medio: 11840.24
#    R^2: -0.5967
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest']:
#    Máximo EA: 55151.82
#    EA Medio: 9763.41
#    R^2: -0.6361
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_southeast']:
#    Máximo EA: 53142.35
#    EA Medio: 10565.36
#    R^2: -0.7955
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_southwest']:
#    Máximo EA: 53142.35
#    EA Medio: 10039.60
#    R^2: -0.7021
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10360.00
#    R^2: -0.7960
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'sex']:
#    Máximo EA: 55151.82
#    EA Medio: 10263.71
#    R^2: -0.7001
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'region_southeast']:
#    Máximo EA: 53142.35
#    EA Medio: 10489.47
#    R^2: -0.7743
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'region_southwest']:
#    Máximo EA: 54107.87
#    EA Medio: 10064.75
#    R^2: -0.7177
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 9937.73
#    R^2: -0.6756
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'sex']:
#    Máximo EA: 55151.82
#    EA Medio: 10384.14
#    R^2: -0.6951
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southeast', 'region_southwest']:
#    Máximo EA: 53142.35
#    EA Medio: 10042.19
#    R^2: -0.6720
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southeast', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10511.69
#    R^2: -0.7881
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southeast', 'sex']:
#    Máximo EA: 52598.70
#    EA Medio: 9956.87
#    R^2: -0.5721
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 9708.82
#    R^2: -0.6296
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southwest', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 9318.80
#    R^2: -0.4728
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'children', 'sex']:
#    Máximo EA: 53775.42
#    EA Medio: 10132.87
#    R^2: -0.6497
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southeast']:
#    Máximo EA: 51771.62
#    EA Medio: 9969.26
#    R^2: -0.5774
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southwest']:
#    Máximo EA: 51771.62
#    EA Medio: 10145.45
#    R^2: -0.6347
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 10363.75
#    R^2: -0.7729
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'sex']:
#    Máximo EA: 54224.05
#    EA Medio: 10934.75
#    R^2: -0.8883
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southeast', 'region_southwest']:
#    Máximo EA: 51771.62
#    EA Medio: 9442.96
#    R^2: -0.5115
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southeast', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 10080.88
#    R^2: -0.7775
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southeast', 'sex']:
#    Máximo EA: 54224.05
#    EA Medio: 11514.21
#    R^2: -1.1010
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southwest', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 9266.10
#    R^2: -0.4980
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southwest', 'sex']:
#    Máximo EA: 54224.05
#    EA Medio: 9962.70
#    R^2: -0.6280
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'children', 'sex']:
#    Máximo EA: 55370.09
#    EA Medio: 10223.58
#    R^2: -0.8494
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 51771.62
#    EA Medio: 9312.16
#    R^2: -0.4470
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 10495.77
#    R^2: -0.7402
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 54809.78
#    EA Medio: 10723.15
#    R^2: -0.8417
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 54695.34
#    EA Medio: 9011.58
#    R^2: -0.4840
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 54813.23
#    EA Medio: 10874.17
#    R^2: -0.8001
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'children', 'sex']:
#    Máximo EA: 54420.05
#    EA Medio: 10075.91
#    R^2: -0.7119
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 54331.18
#    EA Medio: 10601.50
#    R^2: -0.7416
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 53987.51
#    EA Medio: 10838.11
#    R^2: -0.8563
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 53832.81
#    EA Medio: 10539.20
#    R^2: -0.7953
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53832.81
#    EA Medio: 10528.51
#    R^2: -0.7407
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast']:
#    Máximo EA: 56999.59
#    EA Medio: 12640.98
#    R^2: -0.9917
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12498.56
#    R^2: -0.9528
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 11552.26
#    R^2: -0.7508
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'sex']:
#    Máximo EA: 48277.46
#    EA Medio: 12357.32
#    R^2: -0.9096
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_southeast', 'region_southwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12591.18
#    R^2: -0.9704
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_southeast', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 11128.37
#    R^2: -0.7233
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_southeast', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 12465.90
#    R^2: -0.9722
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_southwest', 'children']:
#    Máximo EA: 54087.02
#    EA Medio: 10701.97
#    R^2: -0.6263
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_southwest', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 11868.92
#    R^2: -0.8463
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'children', 'sex']:
#    Máximo EA: 54087.02
#    EA Medio: 11222.38
#    R^2: -0.6509
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12628.63
#    R^2: -0.9795
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 53808.75
#    EA Medio: 10782.67
#    R^2: -0.5947
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 48277.46
#    EA Medio: 11982.95
#    R^2: -0.7978
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 59850.93
#    EA Medio: 10841.30
#    R^2: -0.6820
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 12197.12
#    R^2: -0.9023
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northwest', 'children', 'sex']:
#    Máximo EA: 48693.47
#    EA Medio: 12019.58
#    R^2: -0.8261
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 52389.10
#    EA Medio: 11144.70
#    R^2: -0.6813
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 12376.31
#    R^2: -0.8714
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 50458.37
#    EA Medio: 11538.83
#    R^2: -0.7083
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 54087.02
#    EA Medio: 11802.03
#    R^2: -0.8219
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 49906.39
#    EA Medio: 9988.78
#    R^2: -0.3418
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 10418.43
#    R^2: -0.5089
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 55126.65
#    EA Medio: 11774.12
#    R^2: -0.7022
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 10090.72
#    R^2: -0.3706
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 55126.65
#    EA Medio: 11114.14
#    R^2: -0.5309
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_northwest', 'children', 'sex']:
#    Máximo EA: 47773.74
#    EA Medio: 12801.09
#    R^2: -1.0764
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 47773.74
#    EA Medio: 10703.46
#    R^2: -0.4903
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 55126.65
#    EA Medio: 11244.74
#    R^2: -0.6154
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 47773.74
#    EA Medio: 11961.92
#    R^2: -0.7601
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 47773.74
#    EA Medio: 11876.53
#    R^2: -0.6255
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 49906.39
#    EA Medio: 12175.03
#    R^2: -1.0422
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 55126.65
#    EA Medio: 10785.69
#    R^2: -0.5047
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 56239.56
#    EA Medio: 12728.57
#    R^2: -0.9518
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53791.47
#    EA Medio: 11066.95
#    R^2: -0.4579
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 45757.75
#    EA Medio: 13455.74
#    R^2: -1.0340
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southeast']:
#    Máximo EA: 53142.35
#    EA Medio: 10377.72
#    R^2: -0.7732
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southwest']:
#    Máximo EA: 53142.35
#    EA Medio: 10377.72
#    R^2: -0.7732
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10362.33
#    R^2: -0.7879
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'sex']:
#    Máximo EA: 55151.82
#    EA Medio: 10094.19
#    R^2: -0.6590
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_southeast', 'region_southwest']:
#    Máximo EA: 53142.35
#    EA Medio: 10377.72
#    R^2: -0.7732
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_southeast', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 9709.40
#    R^2: -0.6808
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_southeast', 'sex']:
#    Máximo EA: 52019.32
#    EA Medio: 10324.08
#    R^2: -0.6795
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_southwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10119.18
#    R^2: -0.7551
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'region_southwest', 'sex']:
#    Máximo EA: 52019.32
#    EA Medio: 10271.94
#    R^2: -0.7007
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northeast', 'children', 'sex']:
#    Máximo EA: 52976.23
#    EA Medio: 10115.90
#    R^2: -0.6850
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 53142.35
#    EA Medio: 10377.72
#    R^2: -0.7732
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10221.39
#    R^2: -0.7306
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 52598.70
#    EA Medio: 10802.45
#    R^2: -0.7640
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 9485.18
#    R^2: -0.6184
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 10192.57
#    R^2: -0.6696
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_northwest', 'children', 'sex']:
#    Máximo EA: 53775.42
#    EA Medio: 10036.04
#    R^2: -0.6789
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10253.46
#    R^2: -0.7683
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 52019.32
#    EA Medio: 9522.13
#    R^2: -0.4827
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 52940.62
#    EA Medio: 10041.17
#    R^2: -0.6400
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'bmi', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53775.42
#    EA Medio: 9688.72
#    R^2: -0.5510
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 51771.62
#    EA Medio: 9969.26
#    R^2: -0.5774
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 9811.80
#    R^2: -0.6737
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 54224.05
#    EA Medio: 10775.36
#    R^2: -0.8694
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 9530.49
#    R^2: -0.6113
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 54224.05
#    EA Medio: 10744.89
#    R^2: -0.8823
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_northwest', 'children', 'sex']:
#    Máximo EA: 53852.87
#    EA Medio: 10642.94
#    R^2: -0.8826
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 9806.14
#    R^2: -0.6608
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 54224.05
#    EA Medio: 10354.93
#    R^2: -0.8137
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 53852.87
#    EA Medio: 10069.08
#    R^2: -0.8017
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 55370.09
#    EA Medio: 11085.12
#    R^2: -1.0276
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 54129.86
#    EA Medio: 9484.15
#    R^2: -0.5967
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 54224.05
#    EA Medio: 10217.02
#    R^2: -0.7714
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 53852.87
#    EA Medio: 10702.56
#    R^2: -0.8254
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_northwest', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53852.87
#    EA Medio: 10147.81
#    R^2: -0.7227
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53832.81
#    EA Medio: 10445.90
#    R^2: -0.7906
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 56999.59
#    EA Medio: 12640.98
#    R^2: -0.9917
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10784.43
#    R^2: -0.6209
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 12014.66
#    R^2: -0.8558
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10852.86
#    R^2: -0.6291
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 51177.89
#    EA Medio: 11950.46
#    R^2: -0.8395
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'children', 'sex']:
#    Máximo EA: 44612.17
#    EA Medio: 11519.26
#    R^2: -0.6854
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'region_northeast', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 53903.47
#    EA Medio: 10816.25
# ...
#    Máximo EA: 49406.74
#    EA Medio: 9853.06
#    R^2: -0.2699
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53702.73
#    EA Medio: 9589.05
#    R^2: -0.2573
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 52523.73
#    EA Medio: 10231.96
#    R^2: -0.1547
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 52207.68
#    EA Medio: 9571.20
#    R^2: -0.0822
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 51776.51
#    EA Medio: 10040.59
#    R^2: -0.1371
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 52207.68
#    EA Medio: 9645.00
#    R^2: -0.0932
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 51776.51
#    EA Medio: 10058.99
#    R^2: -0.1392
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'children', 'sex']:
#    Máximo EA: 41916.10
#    EA Medio: 10040.24
#    R^2: -0.1204
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 52207.68
#    EA Medio: 9637.49
#    R^2: -0.0914
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 51776.51
#    EA Medio: 10098.02
#    R^2: -0.1427
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 41946.32
#    EA Medio: 9549.14
#    R^2: -0.0468
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 40500.98
#    EA Medio: 9671.97
#    R^2: -0.0565
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northwest', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 52207.68
#    EA Medio: 9576.29
#    R^2: -0.0775
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northwest', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 51776.51
#    EA Medio: 10059.89
#    R^2: -0.1365
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northwest', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 43628.00
#    EA Medio: 9728.79
#    R^2: -0.0702
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northwest', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53283.10
#    EA Medio: 9904.10
#    R^2: -0.1273
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 51333.43
#    EA Medio: 9876.17
#    R^2: -0.1566
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 42046.62
#    EA Medio: 9974.87
#    R^2: -0.2059
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 47638.74
#    EA Medio: 9354.40
#    R^2: -0.2045
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['region_northeast', 'region_northwest', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 46268.94
#    EA Medio: 9542.38
#    R^2: -0.1308
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['region_northeast', 'region_northwest', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 46268.94
#    EA Medio: 9795.22
#    R^2: -0.1913
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['region_northeast', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 46268.94
#    EA Medio: 9742.17
#    R^2: -0.1666
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['region_northwest', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 46268.94
#    EA Medio: 9590.07
#    R^2: -0.1338
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 53021.71
#    EA Medio: 9885.36
#    R^2: -0.2624
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'children']:
#    Máximo EA: 48281.02
#    EA Medio: 9185.17
#    R^2: -0.1214
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'sex']:
#    Máximo EA: 46217.19
#    EA Medio: 9545.91
#    R^2: -0.1841
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southwest', 'children']:
#    Máximo EA: 48281.02
#    EA Medio: 9185.17
#    R^2: -0.1214
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southwest', 'sex']:
#    Máximo EA: 46217.19
#    EA Medio: 9545.91
#    R^2: -0.1841
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'children', 'sex']:
#    Máximo EA: 49301.69
#    EA Medio: 9273.18
#    R^2: -0.1655
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 48281.02
#    EA Medio: 9185.17
#    R^2: -0.1214
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 46217.19
#    EA Medio: 9545.91
#    R^2: -0.1841
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 49315.84
#    EA Medio: 9036.41
#    R^2: -0.1077
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 49315.05
#    EA Medio: 9081.17
#    R^2: -0.1163
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northwest', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 48281.02
#    EA Medio: 9185.17
#    R^2: -0.1214
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northwest', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 46217.19
#    EA Medio: 9545.85
#    R^2: -0.1841
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northwest', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 53842.64
#    EA Medio: 9005.52
#    R^2: -0.0739
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northwest', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 54333.22
#    EA Medio: 8790.92
#    R^2: -0.0861
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53249.88
#    EA Medio: 9031.23
#    R^2: -0.0625
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 54105.56
#    EA Medio: 9843.01
#    R^2: -0.2735
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 54034.59
#    EA Medio: 9971.63
#    R^2: -0.2966
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 53708.98
#    EA Medio: 9670.45
#    R^2: -0.2814
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53708.98
#    EA Medio: 9662.86
#    R^2: -0.2915
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'region_northeast', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53708.98
#    EA Medio: 9649.67
#    R^2: -0.2778
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'region_northwest', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53708.98
#    EA Medio: 9716.98
#    R^2: -0.2884
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 52207.68
#    EA Medio: 9571.20
#    R^2: -0.0822
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 51776.51
#    EA Medio: 10006.56
#    R^2: -0.1326
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 40346.76
#    EA Medio: 9624.09
#    R^2: -0.0546
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 40346.76
#    EA Medio: 9662.46
#    R^2: -0.0563
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 40346.76
#    EA Medio: 9625.30
#    R^2: -0.0530
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northwest', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 40346.76
#    EA Medio: 9677.74
#    R^2: -0.0574
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 46268.94
#    EA Medio: 9542.38
#    R^2: -0.1308
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'children']:
#    Máximo EA: 48281.02
#    EA Medio: 9185.17
#    R^2: -0.1214
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'sex']:
#    Máximo EA: 46217.19
#    EA Medio: 9545.91
#    R^2: -0.1841
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'children', 'sex']:
#    Máximo EA: 49301.69
#    EA Medio: 8817.51
#    R^2: -0.0594
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 49301.69
#    EA Medio: 8817.51
#    R^2: -0.0594
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 49301.69
#    EA Medio: 8817.51
#    R^2: -0.0594
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northwest', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 49301.69
#    EA Medio: 8817.51
#    R^2: -0.0594
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 53708.98
#    EA Medio: 9670.45
#    R^2: -0.2814
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 40346.76
#    EA Medio: 9624.09
#    R^2: -0.0546
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'children', 'sex']:
#    Máximo EA: 49301.69
#    EA Medio: 8817.51
#    R^2: -0.0594
# ------------------------------------------------------------------------------------------
