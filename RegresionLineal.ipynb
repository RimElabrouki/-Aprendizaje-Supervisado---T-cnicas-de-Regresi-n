# %% [markdown]
# ## Técnica de Regresión Lineal

# %%
import time
import pandas as pd
from itertools import combinations
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, max_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# Cargar datos desde el archivo CSV
df_datos = pd.read_csv("datos/insurance.csv")

# Codificación One Hot para la columna 'region'
codificador_one_hot = OneHotEncoder(sparse=False)
codificacion_one_hot = codificador_one_hot.fit_transform(df_datos[['region']])
arr_nombre_nuevas_columnas = ['region_' + str(cat) for cat in codificador_one_hot.categories_[0]]
df_nuevas_columnas_one_hot = pd.DataFrame(codificacion_one_hot, columns=arr_nombre_nuevas_columnas)
df_datos = pd.concat([df_datos, df_nuevas_columnas_one_hot], axis=1)

# Columnas incluyendo 'region'
columnas_especificas = ['age', 'bmi'] + arr_nombre_nuevas_columnas + ['children', 'sex']

# Crear conjuntos de datos de entrenamiento y prueba para las columnas seleccionadas
df_X = pd.DataFrame(df_datos, columns=columnas_especificas)
df_y = pd.DataFrame(df_datos, columns=['charges'])
df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(df_X, df_y, test_size=0.2, random_state=100)

# Medir tiempo de preprocesamiento
start_time_preprocesamiento = time.time()

# Lista para almacenar los resultados
resultados = []

# Conjunto para rastrear combinaciones únicas
combinaciones_unicas = set()
# Iterar sobre el rango de columnas desde 1 hasta n
for r in range(1, len(columnas_especificas) + 1):
    # Generar combinaciones de tamaño r
    combinaciones_columnas = combinations(columnas_especificas, r)

    # Iterar sobre cada combinación de columnas
    for combo in combinaciones_columnas:
        # Verificar si la combinación ya ha sido procesada
        combinacion_ordenada = tuple(sorted(combo))
        if combinacion_ordenada in combinaciones_unicas:
            continue

        # Agregar la combinación a las combinaciones únicas
        combinaciones_unicas.add(combinacion_ordenada)

        # Crear conjuntos de datos de entrenamiento y prueba para las columnas seleccionadas
        arr_X_train_subset = df_X_train[list(combo)].copy()
        arr_X_test_subset = df_X_test[list(combo)].copy()

        # Utilizar SimpleImputer para llenar valores faltantes con la media
        imputer = SimpleImputer(strategy='mean')
        arr_X_train_subset = imputer.fit_transform(arr_X_train_subset)
        arr_X_test_subset = imputer.transform(arr_X_test_subset)

        # Resto del código para entrenar y evaluar el modelo
        start_time_entrenamiento = time.time()

        # Crear y entrenar el modelo de regresión lineal
        regresion_lineal = linear_model.LinearRegression()
        modelo_regresion_lineal = regresion_lineal.fit(arr_X_train_subset, df_y_train)

        end_time_entrenamiento = time.time()

        # Predicciones
        start_time_prueba = time.time()
        arr_y_test_predicho = modelo_regresion_lineal.predict(arr_X_test_subset)
        end_time_prueba = time.time()

        # Métricas de evaluación del modelo
        max_ea = max_error(df_y_test, arr_y_test_predicho)
        mae = mean_absolute_error(df_y_test, arr_y_test_predicho)
        mse = mean_squared_error(df_y_test, arr_y_test_predicho)
        r2 = r2_score(df_y_test, arr_y_test_predicho)

        # Almacenar resultados en la lista
        resultados.append({
            'Combinación_Columnas': ', '.join(combo),
            'Máximo_EA': max_ea,
            'EA_Medio': mae,
            'R^2': r2,
            'Tiempo_Entrenamiento': end_time_entrenamiento - start_time_entrenamiento,
            'Tiempo_Prueba': end_time_prueba - start_time_prueba
        })

# Crear un DataFrame a partir de la lista de resultados
df_resultados = pd.DataFrame(resultados)

# Calculamos el Error Absoluto Medio (MAE)
df_resultados['EA_Medio'] = df_resultados['EA_Medio'].abs()

# Ordenar el DataFrame por MAE en orden ascendente
df_resultados = df_resultados.sort_values(by='EA_Medio', ascending=True)
# Imprimir el tiempo de preprocesamiento
print(f"Tiempo de preprocesamiento: {time.time() - start_time_preprocesamiento} segundos")
print("**********************************************************************************")
for idx, row in df_resultados.iterrows():
    print(f"{idx + 1:2d}. Combinación: {row['Combinación_Columnas']}")
    print(f"   Máximo EA: {row['Máximo_EA']:.2f}")
    print(f"   EA Medio: {row['EA_Medio']:.2f}")
    print(f"   R^2: {row['R^2']:.4f}")
    print(f"   Tiempo de Entrenamiento: {row['Tiempo_Entrenamiento']:.6f} segundos")
    print(f"   Tiempo de Prueba: {row['Tiempo_Prueba']:.6f} segundos")
    print("-" * 90)
# Out:
# C:\Users\rimel\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Tiempo de preprocesamiento: 5.6281561851501465 segundos
# **********************************************************************************
# 71. Combinación: bmi, region_southwest, sex
#    Máximo EA: 44706.41
#    EA Medio: 8999.75
#    R^2: 0.0547
#    Tiempo de Entrenamiento: 0.007999 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 145. Combinación: bmi, region_southeast, region_southwest, sex
#    Máximo EA: 44984.25
#    EA Medio: 9001.49
#    R^2: 0.0522
#    Tiempo de Entrenamiento: 0.008001 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 67. Combinación: bmi, region_southeast, region_southwest
#    Máximo EA: 45586.16
#    EA Medio: 9004.51
#    R^2: 0.0506
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 19. Combinación: bmi, region_southwest
#    Máximo EA: 45308.62
#    EA Medio: 9006.12
#    R^2: 0.0530
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 136. Combinación: bmi, region_northeast, region_southwest, sex
#    Máximo EA: 44873.57
#    EA Medio: 9011.90
#    R^2: 0.0554
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 60. Combinación: bmi, region_northeast, region_southwest
#    Máximo EA: 45476.91
#    EA Medio: 9020.33
#    R^2: 0.0538
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.008001 segundos
# ------------------------------------------------------------------------------------------
# 18. Combinación: bmi, region_southeast
#    Máximo EA: 45975.77
#    EA Medio: 9024.62
#    R^2: 0.0490
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 69. Combinación: bmi, region_southeast, sex
#    Máximo EA: 45372.80
#    EA Medio: 9028.02
#    R^2: 0.0506
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 205. Combinación: bmi, region_northeast, region_southeast, region_southwest, sex
#    Máximo EA: 45569.06
#    EA Medio: 9028.24
#    R^2: 0.0517
#    Tiempo de Entrenamiento: 0.007982 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 209. Combinación: bmi, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 45569.06
#    EA Medio: 9028.24
#    R^2: 0.0517
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 241. Combinación: bmi, region_northeast, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 45569.06
#    EA Medio: 9028.24
#    R^2: 0.0517
#    Tiempo de Entrenamiento: 0.008017 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 200. Combinación: bmi, region_northeast, region_northwest, region_southeast, sex
#    Máximo EA: 45569.06
#    EA Medio: 9028.24
#    R^2: 0.0517
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 202. Combinación: bmi, region_northeast, region_northwest, region_southwest, sex
#    Máximo EA: 45569.06
#    EA Medio: 9028.24
#    R^2: 0.0517
#    Tiempo de Entrenamiento: 0.007995 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 142. Combinación: bmi, region_northwest, region_southwest, sex
#    Máximo EA: 45568.48
#    EA Medio: 9028.34
#    R^2: 0.0517
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 21. Combinación: bmi, sex
#    Máximo EA: 45016.74
#    EA Medio: 9029.41
#    R^2: 0.0545
#    Tiempo de Entrenamiento: 0.007978 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
#  2. Combinación: bmi
#    Máximo EA: 45619.74
#    EA Medio: 9032.20
#    R^2: 0.0527
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
#
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 29. Combinación: region_northwest, children
#    Máximo EA: 46482.74
#    EA Medio: 9195.60
#    R^2: -0.0083
#    Tiempo de Entrenamiento: 0.007999 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 180. Combinación: age, bmi, region_southeast, region_southwest, sex
#    Máximo EA: 46455.60
#    EA Medio: 9260.15
#    R^2: 0.0692
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 106. Combinación: age, bmi, region_southwest, sex
#    Máximo EA: 45828.90
#    EA Medio: 9262.38
#    R^2: 0.0756
#    Tiempo de Entrenamiento: 0.008001 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 248. Combinación: age, bmi, region_northeast, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 45868.55
#    EA Medio: 9262.50
#    R^2: 0.0694
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 230. Combinación: age, bmi, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 45868.55
#    EA Medio: 9262.50
#    R^2: 0.0694
#    Tiempo de Entrenamiento: 0.004034 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 223. Combinación: age, bmi, region_northeast, region_northwest, region_southwest, sex
#    Máximo EA: 45868.55
#    EA Medio: 9262.50
#    R^2: 0.0694
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 226. Combinación: age, bmi, region_northeast, region_southeast, region_southwest, sex
#    Máximo EA: 45868.55
#    EA Medio: 9262.50
#    R^2: 0.0694
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 221. Combinación: age, bmi, region_northeast, region_northwest, region_southeast, sex
#    Máximo EA: 45868.55
#    EA Medio: 9262.50
#    R^2: 0.0694
#    Tiempo de Entrenamiento: 0.008018 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 171. Combinación: age, bmi, region_northeast, region_southwest, sex
#    Máximo EA: 45620.39
#    EA Medio: 9263.19
#    R^2: 0.0763
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 177. Combinación: age, bmi, region_northwest, region_southwest, sex
#    Máximo EA: 45465.08
#    EA Medio: 9264.02
#    R^2: 0.0717
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 169. Combinación: age, bmi, region_northeast, region_southeast, sex
#    Máximo EA: 45886.24
#    EA Medio: 9270.08
#    R^2: 0.0688
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 233. Combinación: age, bmi, region_southeast, region_southwest, children, sex
#    Máximo EA: 46505.63
#    EA Medio: 9272.64
#    R^2: 0.0679
#    Tiempo de Entrenamiento: 0.007998 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 182. Combinación: age, bmi, region_southwest, children, sex
#    Máximo EA: 45855.05
#    EA Medio: 9274.76
#    R^2: 0.0746
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 252. Combinación: age, bmi, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 45866.85
#    EA Medio: 9275.52
#    R^2: 0.0676
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 250. Combinación: age, bmi, region_northeast, region_northwest, region_southwest, children, sex
#    Máximo EA: 45866.85
#    EA Medio: 9275.52
#    R^2: 0.0676
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 251. Combinación: age, bmi, region_northeast, region_southeast, region_southwest, children, sex
#    Máximo EA: 45866.85
#    EA Medio: 9275.52
#    R^2: 0.0676
#    Tiempo de Entrenamiento: 0.008011 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 249. Combinación: age, bmi, region_northeast, region_northwest, region_southeast, children, sex
#    Máximo EA: 45866.85
#    EA Medio: 9275.52
#    R^2: 0.0676
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 255. Combinación: age, bmi, region_northeast, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 45866.85
#    EA Medio: 9275.52
#    R^2: 0.0676
#    Tiempo de Entrenamiento: 0.007997 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 228. Combinación: age, bmi, region_northeast, region_southwest, children, sex
#    Máximo EA: 45605.72
#    EA Medio: 9275.79
#    R^2: 0.0754
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 232. Combinación: age, bmi, region_northwest, region_southwest, children, sex
#    Máximo EA: 45467.51
#    EA Medio: 9277.03
#    R^2: 0.0699
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 104. Combinación: age, bmi, region_southeast, sex
#    Máximo EA: 46838.88
#    EA Medio: 9281.13
#    R^2: 0.0673
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 15. Combinación: age, sex
#    Máximo EA: 48431.68
#    EA Medio: 9442.38
#    R^2: 0.0307
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 13. Combinación: age, region_southwest
#    Máximo EA: 47399.61
#    EA Medio: 9444.32
#    R^2: 0.0239
#    Tiempo de Entrenamiento: 0.004017 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 51. Combinación: age, region_northwest, sex
#    Máximo EA: 48102.36
#    EA Medio: 9446.58
#    R^2: 0.0295
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 53. Combinación: age, region_southeast, children
#    Máximo EA: 48514.30
#    EA Medio: 9448.73
#    R^2: 0.0160
#    Tiempo de Entrenamiento: 0.008018 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 111. Combinación: age, region_northeast, region_northwest, sex
#    Máximo EA: 48380.11
#    EA Medio: 9449.17
#    R^2: 0.0288
#    Tiempo de Entrenamiento: 0.007995 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 121. Combinación: age, region_northwest, region_southwest, children
#    Máximo EA: 46750.73
#    EA Medio: 9452.80
#    R^2: 0.0192
#    Tiempo de Entrenamiento: 0.008033 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 119. Combinación: age, region_northwest, region_southeast, children
#    Máximo EA: 48332.33
#    EA Medio: 9453.98
#    R^2: 0.0159
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.008019 segundos
# ------------------------------------------------------------------------------------------
# 115. Combinación: age, region_northeast, region_southwest, children
#    Máximo EA: 47698.82
#    EA Medio: 9455.70
#    R^2: 0.0217
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 55. Combinación: age, region_southwest, children
#    Máximo EA: 47435.13
#    EA Medio: 9458.14
#    R^2: 0.0220
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.008002 segundos
# ------------------------------------------------------------------------------------------
# 117. Combinación: age, region_northeast, children, sex
#    Máximo EA: 48352.11
#    EA Medio: 9459.47
#    R^2: 0.0292
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 57. Combinación: age, children, sex
#    Máximo EA: 48448.37
#    EA Medio: 9460.11
#    R^2: 0.0290
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 123. Combinación: age, region_northwest, children, sex
#    Máximo EA: 48101.57
#    EA Medio: 9465.09
#    R^2: 0.0272
#    Tiempo de Entrenamiento: 0.008016 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 188. Combinación: age, region_northeast, region_northwest, children, sex
#    Máximo EA: 48348.16
#    EA Medio: 9467.31
#    R^2: 0.0267
#    Tiempo de Entrenamiento: 0.008000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 10. Combinación: age, region_northeast
#    Máximo EA: 47698.25
#    EA Medio: 9480.70
#    R^2: 0.0239
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
#  1. Combinación: age
#    Máximo EA: 47747.65
#    EA Medio: 9481.05
#    R^2: 0.0238
#    Tiempo de Entrenamiento: 0.489586 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 43. Combinación: age, region_northeast, region_northwest
#    Máximo EA: 47701.08
#    EA Medio: 9487.58
#    R^2: 0.0220
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 11. Combinación: age, region_northwest
#    Máximo EA: 47419.98
#    EA Medio: 9488.16
#    R^2: 0.0227
#    Tiempo de Entrenamiento: 0.008000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 46. Combinación: age, region_northeast, children
#    Máximo EA: 47691.98
#    EA Medio: 9497.19
#    R^2: 0.0220
#    Tiempo de Entrenamiento: 0.008026 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 14. Combinación: age, children
#    Máximo EA: 47790.40
#    EA Medio: 9497.85
#    R^2: 0.0219
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 50. Combinación: age, region_northwest, children
#    Máximo EA: 47445.99
#    EA Medio: 9503.55
#    R^2: 0.0201
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
# 110. Combinación: age, region_northeast, region_northwest, children
#    Máximo EA: 47694.79
#    EA Medio: 9504.73
#    R^2: 0.0196
#    Tiempo de Entrenamiento: 0.000000 segundos
#    Tiempo de Prueba: 0.000000 segundos
# ------------------------------------------------------------------------------------------
