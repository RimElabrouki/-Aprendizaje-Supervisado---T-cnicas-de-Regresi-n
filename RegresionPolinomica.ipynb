# %% [markdown]
# ## Técnica de Regresión Polinómica

# %%
import time
import pandas as pd
from itertools import combinations
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, max_error, r2_score
from sklearn.preprocessing import OneHotEncoder

# Cargar datos desde el archivo CSV
df_datos = pd.read_csv("datos/insurance.csv")

# Codificación One Hot para la columna 'region'
codificador_one_hot = OneHotEncoder(sparse=False)
codificacion_one_hot = codificador_one_hot.fit_transform(df_datos[['region']])
arr_nombre_nuevas_columnas = ['region_' + str(cat) for cat in codificador_one_hot.categories_[0]]
df_nuevas_columnas_one_hot = pd.DataFrame(codificacion_one_hot, columns=arr_nombre_nuevas_columnas)
df_datos = pd.concat([df_datos, df_nuevas_columnas_one_hot], axis=1)

# Columnas incluyendo 'region'
columnas_especificas = ['age', 'bmi'] + arr_nombre_nuevas_columnas + ['children', 'sex']

# Crear conjuntos de datos de entrenamiento y prueba para las columnas seleccionadas
df_X = pd.DataFrame(df_datos, columns=columnas_especificas)
df_y = pd.DataFrame(df_datos, columns=['charges'])
df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(df_X, df_y, test_size=0.2, random_state=100)

# Medir tiempo de preprocesamiento
start_time_preprocesamiento = time.time()

# Lista para almacenar los resultados
resultados_polinomicos = []

# Grados de regresión polinómica
grados_polinomicos = [2, 4, 6]

# Iterar sobre los grados polinómicos
for grado in grados_polinomicos:

    # Conjunto para rastrear combinaciones únicas
    combinaciones_unicas = set()

    # Iterar sobre el rango de columnas desde 1 hasta n
    for r in range(1, len(columnas_especificas) + 1):
        # Generar combinaciones de tamaño r
        combinaciones_columnas = combinations(columnas_especificas, r)

        # Iterar sobre cada combinación de columnas
        for combo in combinaciones_columnas:
            # Verificar si la combinación ya ha sido procesada
            combinacion_ordenada = tuple(sorted(combo))
            if combinacion_ordenada in combinaciones_unicas:
                continue

            # Agregar la combinación a las combinaciones únicas
            combinaciones_unicas.add(combinacion_ordenada)

            # Crear conjuntos de datos de entrenamiento y prueba para las columnas seleccionadas
            arr_X_train_subset = df_X_train[list(combo)].copy()
            arr_X_test_subset = df_X_test[list(combo)].copy()

            # Llenar valores faltantes con el valor medio de la respectiva columna
            arr_X_train_subset.fillna(arr_X_train_subset.mean(), inplace=True)
            arr_X_test_subset.fillna(arr_X_test_subset.mean(), inplace=True)

            # Eliminar filas con valores faltantes en el conjunto de entrenamiento
            indices_train_subset = arr_X_train_subset.dropna().index
            arr_X_train_subset = arr_X_train_subset.loc[indices_train_subset].to_numpy()
            arr_y_train_subset = df_y_train.loc[indices_train_subset].to_numpy()

            # Eliminar filas con valores faltantes en el conjunto de prueba
            indices_test_subset = arr_X_test_subset.dropna().index
            arr_X_test_subset = arr_X_test_subset.loc[indices_test_subset].to_numpy()
            arr_y_test_subset = df_y_test.loc[indices_test_subset].to_numpy()

            # Verificar si hay suficientes muestras para entrenar el modelo
            if len(arr_X_train_subset) == 0 or len(arr_X_test_subset) == 0:
                print(f"No hay suficientes muestras para la combinación {', '.join(combo)}")
                continue

            # Crear y entrenar el modelo de regresión polinómica
            model = make_pipeline(PolynomialFeatures(degree=grado), LinearRegression())
            model.fit(arr_X_train_subset, arr_y_train_subset)

            # Predicciones
            arr_y_test_predicho = model.predict(arr_X_test_subset)

            # Métricas de evaluación del modelo
            max_ea = max_error(arr_y_test_subset, arr_y_test_predicho)
            mae = mean_absolute_error(arr_y_test_subset, arr_y_test_predicho)
            mse = mean_squared_error(arr_y_test_subset, arr_y_test_predicho)
            r2 = r2_score(arr_y_test_subset, arr_y_test_predicho)

            # Almacenar resultados en la lista
            resultados_polinomicos.append({
                'Grado_Polinómico': grado,
                'Combinación_Columnas': ', '.join(combo),
                'Máximo_EA': max_ea,
                'EA_Medio': mae,
                'R^2': r2
            })

# Crear un DataFrame a partir de la lista de resultados
df_resultados_polinomicos = pd.DataFrame(resultados_polinomicos)
#df_resultados_knn = df_resultados_knn.sort_values(by='EA_Medio')
# Imprimir el tiempo de preprocesamiento
print(f"Tiempo de preprocesamiento polinómico: {time.time() - start_time_preprocesamiento} segundos")
print('***************************************************************************************')
# Ordenar el DataFrame por índice en orden ascendente
df_resultados_polinomicos = df_resultados_polinomicos.sort_index()

# Imprimir resultados
for idx, row in df_resultados_polinomicos.iterrows():
    print(f"{idx + 1:2d}. Grado Polinómico: {row['Grado_Polinómico']}, Combinación: {row['Combinación_Columnas']}")
    print(f"   Máximo EA: {row['Máximo_EA']:.2f}")
    print(f"   EA Medio: {row['EA_Medio']:.2f}")
    print(f"   R^2: {row['R^2']:.4f}")
    print("-" * 90)
# Out:
# C:\Users\rimel\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Tiempo de preprocesamiento polinómico: 11.646993160247803 segundos
# ***************************************************************************************
#  1. Grado Polinómico: 2, Combinación: age
#    Máximo EA: 48072.50
#    EA Medio: 9472.05
#    R^2: 0.0243
# ------------------------------------------------------------------------------------------
#  2. Grado Polinómico: 2, Combinación: bmi
#    Máximo EA: 45345.47
#    EA Medio: 9062.06
#    R^2: 0.0500
# ------------------------------------------------------------------------------------------
#  3. Grado Polinómico: 2, Combinación: region_northeast
#    Máximo EA: 46956.50
#    EA Medio: 9093.82
#    R^2: -0.0067
# ------------------------------------------------------------------------------------------
#  4. Grado Polinómico: 2, Combinación: region_northwest
#    Máximo EA: 47824.50
#    EA Medio: 9120.18
#    R^2: -0.0072
# ------------------------------------------------------------------------------------------
#  5. Grado Polinómico: 2, Combinación: region_southeast
#    Máximo EA: 47538.50
#    EA Medio: 9075.37
#    R^2: -0.0075
# ------------------------------------------------------------------------------------------
#  6. Grado Polinómico: 2, Combinación: region_southwest
#    Máximo EA: 46573.50
#    EA Medio: 9057.50
#    R^2: -0.0068
# ------------------------------------------------------------------------------------------
#  7. Grado Polinómico: 2, Combinación: children
#    Máximo EA: 45553.80
#    EA Medio: 9124.56
#    R^2: 0.0018
# ------------------------------------------------------------------------------------------
#  8. Grado Polinómico: 2, Combinación: sex
#    Máximo EA: 46332.50
#    EA Medio: 9095.33
#    R^2: -0.0035
# ------------------------------------------------------------------------------------------
#  9. Grado Polinómico: 2, Combinación: age, bmi
#    Máximo EA: 45732.55
#    EA Medio: 9323.35
#    R^2: 0.0713
# ------------------------------------------------------------------------------------------
# 10. Grado Polinómico: 2, Combinación: age, region_northeast
#    Máximo EA: 47748.56
#    EA Medio: 9476.97
#    R^2: 0.0231
# ------------------------------------------------------------------------------------------
# 11. Grado Polinómico: 2, Combinación: age, region_northwest
#    Máximo EA: 47729.68
#    EA Medio: 9478.55
#    R^2: 0.0235
# ------------------------------------------------------------------------------------------
# 12. Grado Polinómico: 2, Combinación: age, region_southeast
#    Máximo EA: 48623.23
#    EA Medio: 9410.03
#    R^2: 0.0199
# ------------------------------------------------------------------------------------------
# 13. Grado Polinómico: 2, Combinación: age, region_southwest
#    Máximo EA: 47792.69
#    EA Medio: 9426.83
#    R^2: 0.0262
# ------------------------------------------------------------------------------------------
# 14. Grado Polinómico: 2, Combinación: age, children
#    Máximo EA: 47945.32
#    EA Medio: 9399.70
#    R^2: 0.0325
# ------------------------------------------------------------------------------------------
# 15. Grado Polinómico: 2, Combinación: age, sex
#    Máximo EA: 48612.53
#    EA Medio: 9435.18
#    R^2: 0.0273
# ------------------------------------------------------------------------------------------
# 16. Grado Polinómico: 2, Combinación: bmi, region_northeast
#    Máximo EA: 45576.35
#    EA Medio: 9092.63
#    R^2: 0.0509
# ------------------------------------------------------------------------------------------
# 17. Grado Polinómico: 2, Combinación: bmi, region_northwest
#    Máximo EA: 46161.37
#    EA Medio: 9087.69
#    R^2: 0.0478
# ------------------------------------------------------------------------------------------
# 18. Grado Polinómico: 2, Combinación: bmi, region_southeast
#    Máximo EA: 45748.27
#    EA Medio: 9063.90
#    R^2: 0.0444
# ------------------------------------------------------------------------------------------
# 19. Grado Polinómico: 2, Combinación: bmi, region_southwest
#    Máximo EA: 44943.11
#    EA Medio: 9049.03
#    R^2: 0.0473
# ------------------------------------------------------------------------------------------
# 20. Grado Polinómico: 2, Combinación: bmi, children
#    Máximo EA: 43754.15
#    EA Medio: 9078.42
#    R^2: 0.0566
# ------------------------------------------------------------------------------------------
# 21. Grado Polinómico: 2, Combinación: bmi, sex
#    Máximo EA: 44511.89
#    EA Medio: 9101.49
#    R^2: 0.0474
# ------------------------------------------------------------------------------------------
# 22. Grado Polinómico: 2, Combinación: region_northeast, region_northwest
#    Máximo EA: 47923.00
#    EA Medio: 9125.99
#    R^2: -0.0075
# ------------------------------------------------------------------------------------------
# 23. Grado Polinómico: 2, Combinación: region_northeast, region_southeast
#    Máximo EA: 47927.88
#    EA Medio: 9075.60
#    R^2: -0.0079
# ------------------------------------------------------------------------------------------
# 24. Grado Polinómico: 2, Combinación: region_northeast, region_southwest
#    Máximo EA: 46508.50
#    EA Medio: 9055.93
#    R^2: -0.0064
# ------------------------------------------------------------------------------------------
# 25. Grado Polinómico: 2, Combinación: region_northeast, children
#    Máximo EA: 45752.20
#    EA Medio: 9142.96
#    R^2: -0.0001
# ------------------------------------------------------------------------------------------
# 26. Grado Polinómico: 2, Combinación: region_northeast, sex
#    Máximo EA: 46559.38
#    EA Medio: 9142.11
#    R^2: -0.0108
# ------------------------------------------------------------------------------------------
# 27. Grado Polinómico: 2, Combinación: region_northwest, region_southeast
#    Máximo EA: 47823.75
#    EA Medio: 9085.81
#    R^2: -0.0080
# ------------------------------------------------------------------------------------------
# 28. Grado Polinómico: 2, Combinación: region_northwest, region_southwest
#    Máximo EA: 47831.00
#    EA Medio: 9084.41
#    R^2: -0.0074
# ------------------------------------------------------------------------------------------
# 29. Grado Polinómico: 2, Combinación: region_northwest, children
#    Máximo EA: 45801.51
#    EA Medio: 9135.59
#    R^2: 0.0049
# ------------------------------------------------------------------------------------------
# 30. Grado Polinómico: 2, Combinación: region_northwest, sex
#    Máximo EA: 48251.31
#    EA Medio: 9170.82
#    R^2: -0.0074
# ------------------------------------------------------------------------------------------
# 31. Grado Polinómico: 2, Combinación: region_southeast, region_southwest
#    Máximo EA: 47363.50
#    EA Medio: 9061.79
#    R^2: -0.0071
# ------------------------------------------------------------------------------------------
# 32. Grado Polinómico: 2, Combinación: region_southeast, children
#    Máximo EA: 46189.68
#    EA Medio: 9092.21
#    R^2: 0.0006
# ------------------------------------------------------------------------------------------
# 33. Grado Polinómico: 2, Combinación: region_southeast, sex
#    Máximo EA: 47121.36
#    EA Medio: 9065.21
#    R^2: -0.0056
# ------------------------------------------------------------------------------------------
# 34. Grado Polinómico: 2, Combinación: region_southwest, children
#    Máximo EA: 44832.75
#    EA Medio: 9134.49
#    R^2: -0.0022
# ------------------------------------------------------------------------------------------
# 35. Grado Polinómico: 2, Combinación: region_southwest, sex
#    Máximo EA: 45930.87
#    EA Medio: 9074.00
#    R^2: -0.0055
# ------------------------------------------------------------------------------------------
# 36. Grado Polinómico: 2, Combinación: children, sex
#    Máximo EA: 45712.27
#    EA Medio: 9110.57
#    R^2: 0.0049
# ------------------------------------------------------------------------------------------
# 37. Grado Polinómico: 2, Combinación: age, bmi, region_northeast
#    Máximo EA: 44276.55
#    EA Medio: 9351.37
#    R^2: 0.0712
# ------------------------------------------------------------------------------------------
# 38. Grado Polinómico: 2, Combinación: age, bmi, region_northwest
#    Máximo EA: 45511.22
#    EA Medio: 9338.97
#    R^2: 0.0691
# ------------------------------------------------------------------------------------------
# 39. Grado Polinómico: 2, Combinación: age, bmi, region_southeast
#    Máximo EA: 46364.06
#    EA Medio: 9312.57
#    R^2: 0.0618
# ------------------------------------------------------------------------------------------
# 40. Grado Polinómico: 2, Combinación: age, bmi, region_southwest
#    Máximo EA: 45267.06
#    EA Medio: 9336.34
#    R^2: 0.0625
# ------------------------------------------------------------------------------------------
# 41. Grado Polinómico: 2, Combinación: age, bmi, children
#    Máximo EA: 45639.52
#    EA Medio: 9263.52
#    R^2: 0.0779
# ------------------------------------------------------------------------------------------
# 42. Grado Polinómico: 2, Combinación: age, bmi, sex
#    Máximo EA: 47110.34
#    EA Medio: 9295.66
#    R^2: 0.0715
# ------------------------------------------------------------------------------------------
# 43. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest
#    Máximo EA: 47739.76
#    EA Medio: 9484.30
#    R^2: 0.0213
# ------------------------------------------------------------------------------------------
# 44. Grado Polinómico: 2, Combinación: age, region_northeast, region_southeast
#    Máximo EA: 47748.56
#    EA Medio: 9406.12
#    R^2: 0.0198
# ------------------------------------------------------------------------------------------
# 45. Grado Polinómico: 2, Combinación: age, region_northeast, region_southwest
#    Máximo EA: 47757.14
#    EA Medio: 9425.70
#    R^2: 0.0250
# ------------------------------------------------------------------------------------------
# 46. Grado Polinómico: 2, Combinación: age, region_northeast, children
#    Máximo EA: 47599.01
#    EA Medio: 9435.42
#    R^2: 0.0276
# ------------------------------------------------------------------------------------------
# 47. Grado Polinómico: 2, Combinación: age, region_northeast, sex
#    Máximo EA: 48675.16
#    EA Medio: 9456.80
#    R^2: 0.0207
# ------------------------------------------------------------------------------------------
# 48. Grado Polinómico: 2, Combinación: age, region_northwest, region_southeast
#    Máximo EA: 48374.33
#    EA Medio: 9414.50
#    R^2: 0.0206
# ------------------------------------------------------------------------------------------
# 49. Grado Polinómico: 2, Combinación: age, region_northwest, region_southwest
#    Máximo EA: 47152.19
#    EA Medio: 9421.90
#    R^2: 0.0245
# ------------------------------------------------------------------------------------------
# 50. Grado Polinómico: 2, Combinación: age, region_northwest, children
#    Máximo EA: 47576.58
#    EA Medio: 9381.07
#    R^2: 0.0351
# ------------------------------------------------------------------------------------------
# 51. Grado Polinómico: 2, Combinación: age, region_northwest, sex
#    Máximo EA: 48563.95
#    EA Medio: 9446.05
#    R^2: 0.0245
# ------------------------------------------------------------------------------------------
# 52. Grado Polinómico: 2, Combinación: age, region_southeast, region_southwest
#    Máximo EA: 48448.61
#    EA Medio: 9396.39
#    R^2: 0.0209
# ------------------------------------------------------------------------------------------
# 53. Grado Polinómico: 2, Combinación: age, region_southeast, children
#    Máximo EA: 48529.79
#    EA Medio: 9338.43
#    R^2: 0.0307
# ------------------------------------------------------------------------------------------
# 54. Grado Polinómico: 2, Combinación: age, region_southeast, sex
#    Máximo EA: 48884.55
#    EA Medio: 9392.08
#    R^2: 0.0190
# ------------------------------------------------------------------------------------------
# 55. Grado Polinómico: 2, Combinación: age, region_southwest, children
#    Máximo EA: 47712.49
#    EA Medio: 9369.69
#    R^2: 0.0302
# ------------------------------------------------------------------------------------------
# 56. Grado Polinómico: 2, Combinación: age, region_southwest, sex
#    Máximo EA: 48411.66
#    EA Medio: 9402.42
#    R^2: 0.0257
# ------------------------------------------------------------------------------------------
# 57. Grado Polinómico: 2, Combinación: age, children, sex
#    Máximo EA: 48417.74
#    EA Medio: 9364.23
#    R^2: 0.0346
# ------------------------------------------------------------------------------------------
# 58. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest
#    Máximo EA: 46161.39
#    EA Medio: 9104.27
#    R^2: 0.0493
# ------------------------------------------------------------------------------------------
# 59. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southeast
#    Máximo EA: 46346.08
#    EA Medio: 9106.20
#    R^2: 0.0427
# ------------------------------------------------------------------------------------------
# 60. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southwest
#    Máximo EA: 45147.52
#    EA Medio: 9073.16
#    R^2: 0.0478
# ------------------------------------------------------------------------------------------
# 61. Grado Polinómico: 2, Combinación: bmi, region_northeast, children
#    Máximo EA: 44168.89
#    EA Medio: 9137.13
#    R^2: 0.0533
# ------------------------------------------------------------------------------------------
# 62. Grado Polinómico: 2, Combinación: bmi, region_northeast, sex
#    Máximo EA: 44723.06
#    EA Medio: 9171.87
#    R^2: 0.0392
# ------------------------------------------------------------------------------------------
# 63. Grado Polinómico: 2, Combinación: bmi, region_northwest, region_southeast
#    Máximo EA: 46159.01
#    EA Medio: 9077.22
#    R^2: 0.0441
# ------------------------------------------------------------------------------------------
# 64. Grado Polinómico: 2, Combinación: bmi, region_northwest, region_southwest
#    Máximo EA: 46156.96
#    EA Medio: 9090.75
#    R^2: 0.0431
# ------------------------------------------------------------------------------------------
# 65. Grado Polinómico: 2, Combinación: bmi, region_northwest, children
#    Máximo EA: 43954.82
#    EA Medio: 9094.35
#    R^2: 0.0568
# ------------------------------------------------------------------------------------------
# 66. Grado Polinómico: 2, Combinación: bmi, region_northwest, sex
#    Máximo EA: 45780.07
#    EA Medio: 9130.73
#    R^2: 0.0435
# ------------------------------------------------------------------------------------------
# 67. Grado Polinómico: 2, Combinación: bmi, region_southeast, region_southwest
#    Máximo EA: 45262.49
#    EA Medio: 9045.63
#    R^2: 0.0452
# ------------------------------------------------------------------------------------------
# 68. Grado Polinómico: 2, Combinación: bmi, region_southeast, children
#    Máximo EA: 44209.03
#    EA Medio: 9073.65
#    R^2: 0.0493
# ------------------------------------------------------------------------------------------
# 69. Grado Polinómico: 2, Combinación: bmi, region_southeast, sex
#    Máximo EA: 44834.99
#    EA Medio: 9081.20
#    R^2: 0.0425
# ------------------------------------------------------------------------------------------
# 70. Grado Polinómico: 2, Combinación: bmi, region_southwest, children
#    Máximo EA: 42720.82
#    EA Medio: 9108.64
#    R^2: 0.0474
# ------------------------------------------------------------------------------------------
# 71. Grado Polinómico: 2, Combinación: bmi, region_southwest, sex
#    Máximo EA: 44182.65
#    EA Medio: 9092.45
#    R^2: 0.0416
# ------------------------------------------------------------------------------------------
# 72. Grado Polinómico: 2, Combinación: bmi, children, sex
#    Máximo EA: 44116.30
#    EA Medio: 9088.03
#    R^2: 0.0555
# ------------------------------------------------------------------------------------------
# 73. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, region_southeast
#    Máximo EA: 48076.50
#    EA Medio: 9083.87
#    R^2: -0.0105
# ------------------------------------------------------------------------------------------
# 74. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, region_southwest
#    Máximo EA: 47946.50
#    EA Medio: 9078.83
#    R^2: -0.0101
# ------------------------------------------------------------------------------------------
# 75. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, children
#    Máximo EA: 45636.50
#    EA Medio: 9165.88
#    R^2: 0.0021
# ------------------------------------------------------------------------------------------
# 76. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, sex
#    Máximo EA: 48540.50
#    EA Medio: 9190.13
#    R^2: -0.0112
# ------------------------------------------------------------------------------------------
# 77. Grado Polinómico: 2, Combinación: region_northeast, region_southeast, region_southwest
#    Máximo EA: 47908.50
#    EA Medio: 9074.68
#    R^2: -0.0079
# ------------------------------------------------------------------------------------------
# 78. Grado Polinómico: 2, Combinación: region_northeast, region_southeast, children
#    Máximo EA: 46590.50
#    EA Medio: 9134.02
#    R^2: -0.0028
# ------------------------------------------------------------------------------------------
# 79. Grado Polinómico: 2, Combinación: region_northeast, region_southeast, sex
#    Máximo EA: 48260.50
#    EA Medio: 9161.92
#    R^2: -0.0194
# ------------------------------------------------------------------------------------------
# 80. Grado Polinómico: 2, Combinación: region_northeast, region_southwest, children
#    Máximo EA: 44907.24
#    EA Medio: 9135.48
#    R^2: -0.0022
# ------------------------------------------------------------------------------------------
# 81. Grado Polinómico: 2, Combinación: region_northeast, region_southwest, sex
#    Máximo EA: 46514.18
#    EA Medio: 9104.77
#    R^2: -0.0111
# ------------------------------------------------------------------------------------------
# 82. Grado Polinómico: 2, Combinación: region_northeast, children, sex
#    Máximo EA: 46038.46
#    EA Medio: 9170.90
#    R^2: -0.0051
# ------------------------------------------------------------------------------------------
# 83. Grado Polinómico: 2, Combinación: region_northwest, region_southeast, region_southwest
#    Máximo EA: 47818.50
#    EA Medio: 9072.56
#    R^2: -0.0087
# ------------------------------------------------------------------------------------------
# 84. Grado Polinómico: 2, Combinación: region_northwest, region_southeast, children
#    Máximo EA: 45648.18
#    EA Medio: 9092.04
#    R^2: 0.0037
# ------------------------------------------------------------------------------------------
# 85. Grado Polinómico: 2, Combinación: region_northwest, region_southeast, sex
#    Máximo EA: 48340.00
#    EA Medio: 9116.18
#    R^2: -0.0085
# ------------------------------------------------------------------------------------------
# 86. Grado Polinómico: 2, Combinación: region_northwest, region_southwest, children
#    Máximo EA: 45548.00
#    EA Medio: 9149.39
#    R^2: -0.0006
# ------------------------------------------------------------------------------------------
# 87. Grado Polinómico: 2, Combinación: region_northwest, region_southwest, sex
#    Máximo EA: 48360.00
#    EA Medio: 9159.46
#    R^2: -0.0147
# ------------------------------------------------------------------------------------------
# 88. Grado Polinómico: 2, Combinación: region_northwest, children, sex
#    Máximo EA: 45747.28
#    EA Medio: 9200.90
#    R^2: 0.0038
# ------------------------------------------------------------------------------------------
# 89. Grado Polinómico: 2, Combinación: region_southeast, region_southwest, children
#    Máximo EA: 45598.18
#    EA Medio: 9121.42
#    R^2: -0.0016
# ------------------------------------------------------------------------------------------
# 90. Grado Polinómico: 2, Combinación: region_southeast, region_southwest, sex
#    Máximo EA: 47161.50
#    EA Medio: 9048.17
#    R^2: -0.0047
# ------------------------------------------------------------------------------------------
# 91. Grado Polinómico: 2, Combinación: region_southeast, children, sex
#    Máximo EA: 46120.97
#    EA Medio: 9103.60
#    R^2: 0.0017
# ------------------------------------------------------------------------------------------
# 92. Grado Polinómico: 2, Combinación: region_southwest, children, sex
#    Máximo EA: 45259.29
#    EA Medio: 9143.31
#    R^2: -0.0025
# ------------------------------------------------------------------------------------------
# 93. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_northwest
#    Máximo EA: 44271.67
#    EA Medio: 9364.92
#    R^2: 0.0684
# ------------------------------------------------------------------------------------------
# 94. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_southeast
#    Máximo EA: 44351.53
#    EA Medio: 9361.97
#    R^2: 0.0573
# ------------------------------------------------------------------------------------------
# 95. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_southwest
#    Máximo EA: 44369.72
#    EA Medio: 9350.37
#    R^2: 0.0633
# ------------------------------------------------------------------------------------------
# 96. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, children
#    Máximo EA: 44075.61
#    EA Medio: 9322.04
#    R^2: 0.0722
# ------------------------------------------------------------------------------------------
# 97. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, sex
#    Máximo EA: 46128.77
#    EA Medio: 9362.37
#    R^2: 0.0635
# ------------------------------------------------------------------------------------------
# 98. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, region_southeast
#    Máximo EA: 46120.00
#    EA Medio: 9316.14
#    R^2: 0.0626
# ------------------------------------------------------------------------------------------
# 99. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, region_southwest
#    Máximo EA: 44796.87
#    EA Medio: 9356.12
#    R^2: 0.0576
# ------------------------------------------------------------------------------------------
# 100. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, children
#    Máximo EA: 45373.52
#    EA Medio: 9257.23
#    R^2: 0.0782
# ------------------------------------------------------------------------------------------
# 101. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, sex
#    Máximo EA: 47070.18
#    EA Medio: 9315.96
#    R^2: 0.0679
# ------------------------------------------------------------------------------------------
# 102. Grado Polinómico: 2, Combinación: age, bmi, region_southeast, region_southwest
#    Máximo EA: 45610.38
#    EA Medio: 9325.49
#    R^2: 0.0583
# ------------------------------------------------------------------------------------------
# 103. Grado Polinómico: 2, Combinación: age, bmi, region_southeast, children
#    Máximo EA: 46395.92
#    EA Medio: 9254.06
#    R^2: 0.0691
# ------------------------------------------------------------------------------------------
# 104. Grado Polinómico: 2, Combinación: age, bmi, region_southeast, sex
#    Máximo EA: 47413.54
#    EA Medio: 9290.93
#    R^2: 0.0603
# ------------------------------------------------------------------------------------------
# 105. Grado Polinómico: 2, Combinación: age, bmi, region_southwest, children
#    Máximo EA: 45176.78
#    EA Medio: 9295.41
#    R^2: 0.0638
# ------------------------------------------------------------------------------------------
# 106. Grado Polinómico: 2, Combinación: age, bmi, region_southwest, sex
#    Máximo EA: 46741.10
#    EA Medio: 9323.64
#    R^2: 0.0587
# ------------------------------------------------------------------------------------------
# 107. Grado Polinómico: 2, Combinación: age, bmi, children, sex
#    Máximo EA: 46933.96
#    EA Medio: 9233.01
#    R^2: 0.0786
# ------------------------------------------------------------------------------------------
# 108. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, region_southeast
#    Máximo EA: 47748.74
#    EA Medio: 9401.31
#    R^2: 0.0209
# ------------------------------------------------------------------------------------------
# 109. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, region_southwest
#    Máximo EA: 47748.74
#    EA Medio: 9401.31
#    R^2: 0.0209
# ------------------------------------------------------------------------------------------
# 110. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, children
#    Máximo EA: 47607.39
#    EA Medio: 9415.26
#    R^2: 0.0297
# ------------------------------------------------------------------------------------------
# 111. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, sex
#    Máximo EA: 48669.88
#    EA Medio: 9457.38
#    R^2: 0.0202
# ------------------------------------------------------------------------------------------
# 112. Grado Polinómico: 2, Combinación: age, region_northeast, region_southeast, region_southwest
#    Máximo EA: 47748.74
#    EA Medio: 9401.31
#    R^2: 0.0209
# ------------------------------------------------------------------------------------------
# 113. Grado Polinómico: 2, Combinación: age, region_northeast, region_southeast, children
#    Máximo EA: 47622.12
#    EA Medio: 9359.55
#    R^2: 0.0262
# ------------------------------------------------------------------------------------------
# 114. Grado Polinómico: 2, Combinación: age, region_northeast, region_southeast, sex
#    Máximo EA: 48661.61
#    EA Medio: 9422.47
#    R^2: 0.0088
# ------------------------------------------------------------------------------------------
# 115. Grado Polinómico: 2, Combinación: age, region_northeast, region_southwest, children
#    Máximo EA: 47628.86
#    EA Medio: 9389.31
#    R^2: 0.0274
# ------------------------------------------------------------------------------------------
# 116. Grado Polinómico: 2, Combinación: age, region_northeast, region_southwest, sex
#    Máximo EA: 48677.23
#    EA Medio: 9410.50
#    R^2: 0.0208
# ------------------------------------------------------------------------------------------
# 117. Grado Polinómico: 2, Combinación: age, region_northeast, children, sex
#    Máximo EA: 48497.89
#    EA Medio: 9415.41
#    R^2: 0.0241
# ------------------------------------------------------------------------------------------
# 118. Grado Polinómico: 2, Combinación: age, region_northwest, region_southeast, region_southwest
#    Máximo EA: 47748.74
#    EA Medio: 9401.31
#    R^2: 0.0209
# ------------------------------------------------------------------------------------------
# 119. Grado Polinómico: 2, Combinación: age, region_northwest, region_southeast, children
#    Máximo EA: 48227.99
#    EA Medio: 9320.99
#    R^2: 0.0338
# ------------------------------------------------------------------------------------------
# 120. Grado Polinómico: 2, Combinación: age, region_northwest, region_southeast, sex
#    Máximo EA: 48968.73
#    EA Medio: 9396.18
#    R^2: 0.0188
# ------------------------------------------------------------------------------------------
# 121. Grado Polinómico: 2, Combinación: age, region_northwest, region_southwest, children
#    Máximo EA: 47037.68
#    EA Medio: 9350.57
#    R^2: 0.0301
# ------------------------------------------------------------------------------------------
# 122. Grado Polinómico: 2, Combinación: age, region_northwest, region_southwest, sex
#    Máximo EA: 48238.70
#    EA Medio: 9422.73
#    R^2: 0.0169
# ------------------------------------------------------------------------------------------
# 123. Grado Polinómico: 2, Combinación: age, region_northwest, children, sex
#    Máximo EA: 48380.74
#    EA Medio: 9344.05
#    R^2: 0.0344
# ------------------------------------------------------------------------------------------
# 124. Grado Polinómico: 2, Combinación: age, region_southeast, region_southwest, children
#    Máximo EA: 48425.72
#    EA Medio: 9338.03
#    R^2: 0.0284
# ------------------------------------------------------------------------------------------
# 125. Grado Polinómico: 2, Combinación: age, region_southeast, region_southwest, sex
#    Máximo EA: 48702.90
#    EA Medio: 9377.99
#    R^2: 0.0200
# ------------------------------------------------------------------------------------------
# 126. Grado Polinómico: 2, Combinación: age, region_southeast, children, sex
#    Máximo EA: 48705.53
#    EA Medio: 9313.03
#    R^2: 0.0270
# ------------------------------------------------------------------------------------------
# 127. Grado Polinómico: 2, Combinación: age, region_southwest, children, sex
#    Máximo EA: 48260.01
#    EA Medio: 9355.92
#    R^2: 0.0280
# ------------------------------------------------------------------------------------------
# 128. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, region_southeast
#    Máximo EA: 46158.17
#    EA Medio: 9093.58
#    R^2: 0.0436
# ------------------------------------------------------------------------------------------
# 129. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, region_southwest
#    Máximo EA: 46158.17
#    EA Medio: 9093.58
#    R^2: 0.0436
# ------------------------------------------------------------------------------------------
# 130. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, children
#    Máximo EA: 43855.07
#    EA Medio: 9152.91
#    R^2: 0.0532
# ------------------------------------------------------------------------------------------
# 131. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, sex
#    Máximo EA: 45698.57
#    EA Medio: 9178.62
#    R^2: 0.0387
# ------------------------------------------------------------------------------------------
# 132. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southeast, region_southwest
#    Máximo EA: 46158.17
#    EA Medio: 9093.58
#    R^2: 0.0436
# ------------------------------------------------------------------------------------------
# 133. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southeast, children
#    Máximo EA: 45056.36
#    EA Medio: 9150.85
#    R^2: 0.0417
# ------------------------------------------------------------------------------------------
# 134. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southeast, sex
#    Máximo EA: 45742.91
#    EA Medio: 9173.49
#    R^2: 0.0294
# ------------------------------------------------------------------------------------------
# 135. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southwest, children
#    Máximo EA: 43049.18
#    EA Medio: 9142.96
#    R^2: 0.0465
# ------------------------------------------------------------------------------------------
# 136. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southwest, sex
#    Máximo EA: 44265.64
#    EA Medio: 9150.49
#    R^2: 0.0358
# ------------------------------------------------------------------------------------------
# 137. Grado Polinómico: 2, Combinación: bmi, region_northeast, children, sex
#    Máximo EA: 43418.25
#    EA Medio: 9196.38
#    R^2: 0.0435
# ------------------------------------------------------------------------------------------
# 138. Grado Polinómico: 2, Combinación: bmi, region_northwest, region_southeast, region_southwest
#    Máximo EA: 46158.17
#    EA Medio: 9093.58
#    R^2: 0.0436
# ------------------------------------------------------------------------------------------
# 139. Grado Polinómico: 2, Combinación: bmi, region_northwest, region_southeast, children
#    Máximo EA: 43952.44
#    EA Medio: 9076.79
#    R^2: 0.0515
# ------------------------------------------------------------------------------------------
# 140. Grado Polinómico: 2, Combinación: bmi, region_northwest, region_southeast, sex
#    Máximo EA: 45792.57
#    EA Medio: 9110.88
#    R^2: 0.0404
# ------------------------------------------------------------------------------------------
# 141. Grado Polinómico: 2, Combinación: bmi, region_northwest, region_southwest, children
#    Máximo EA: 43866.52
#    EA Medio: 9145.50
#    R^2: 0.0425
# ------------------------------------------------------------------------------------------
# 142. Grado Polinómico: 2, Combinación: bmi, region_northwest, region_southwest, sex
#    Máximo EA: 45779.85
#    EA Medio: 9140.14
#    R^2: 0.0325
# ------------------------------------------------------------------------------------------
# 143. Grado Polinómico: 2, Combinación: bmi, region_northwest, children, sex
#    Máximo EA: 44027.51
#    EA Medio: 9122.09
#    R^2: 0.0532
# ------------------------------------------------------------------------------------------
# 144. Grado Polinómico: 2, Combinación: bmi, region_southeast, region_southwest, children
#    Máximo EA: 42866.56
#    EA Medio: 9098.72
#    R^2: 0.0451
# ------------------------------------------------------------------------------------------
# 145. Grado Polinómico: 2, Combinación: bmi, region_southeast, region_southwest, sex
#    Máximo EA: 44286.42
#    EA Medio: 9078.92
#    R^2: 0.0410
# ------------------------------------------------------------------------------------------
# 146. Grado Polinómico: 2, Combinación: bmi, region_southeast, children, sex
#    Máximo EA: 44509.82
#    EA Medio: 9088.61
#    R^2: 0.0486
# ------------------------------------------------------------------------------------------
# 147. Grado Polinómico: 2, Combinación: bmi, region_southwest, children, sex
#    Máximo EA: 43813.65
#    EA Medio: 9141.86
#    R^2: 0.0443
# ------------------------------------------------------------------------------------------
# 148. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, region_southeast, region_southwest
#    Máximo EA: 47940.40
#    EA Medio: 9073.57
#    R^2: -0.0099
# ------------------------------------------------------------------------------------------
# 149. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, region_southeast, children
#    Máximo EA: 45775.18
#    EA Medio: 9132.33
#    R^2: -0.0010
# ------------------------------------------------------------------------------------------
# 150. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, region_southeast, sex
#    Máximo EA: 48396.50
#    EA Medio: 9145.89
#    R^2: -0.0170
# ------------------------------------------------------------------------------------------
# 151. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, region_southwest, children
#    Máximo EA: 45678.75
#    EA Medio: 9130.77
#    R^2: -0.0008
# ------------------------------------------------------------------------------------------
# 152. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, region_southwest, sex
#    Máximo EA: 48416.50
#    EA Medio: 9149.93
#    R^2: -0.0166
# ------------------------------------------------------------------------------------------
# 153. Grado Polinómico: 2, Combinación: region_northeast, region_northwest, children, sex
#    Máximo EA: 46158.62
#    EA Medio: 9228.10
#    R^2: -0.0016
# ------------------------------------------------------------------------------------------
# 154. Grado Polinómico: 2, Combinación: region_northeast, region_southeast, region_southwest, children
#    Máximo EA: 46232.50
#    EA Medio: 9146.66
#    R^2: -0.0011
# ------------------------------------------------------------------------------------------
# 155. Grado Polinómico: 2, Combinación: region_northeast, region_southeast, region_southwest, sex
#    Máximo EA: 48728.50
#    EA Medio: 9168.87
#    R^2: -0.0166
# ------------------------------------------------------------------------------------------
# 156. Grado Polinómico: 2, Combinación: region_northeast, region_southeast, children, sex
#    Máximo EA: 46296.00
#    EA Medio: 9210.36
#    R^2: -0.0151
# ------------------------------------------------------------------------------------------
# 157. Grado Polinómico: 2, Combinación: region_northeast, region_southwest, children, sex
#    Máximo EA: 46096.12
#    EA Medio: 9169.81
#    R^2: -0.0078
# ------------------------------------------------------------------------------------------
# 158. Grado Polinómico: 2, Combinación: region_northwest, region_southeast, region_southwest, children
#    Máximo EA: 45527.00
#    EA Medio: 9126.06
#    R^2: -0.0023
# ------------------------------------------------------------------------------------------
# 159. Grado Polinómico: 2, Combinación: region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 48360.50
#    EA Medio: 9150.32
#    R^2: -0.0164
# ------------------------------------------------------------------------------------------
# 160. Grado Polinómico: 2, Combinación: region_northwest, region_southeast, children, sex
#    Máximo EA: 46444.18
#    EA Medio: 9150.63
#    R^2: 0.0016
# ------------------------------------------------------------------------------------------
# 161. Grado Polinómico: 2, Combinación: region_northwest, region_southwest, children, sex
#    Máximo EA: 45485.91
#    EA Medio: 9240.32
#    R^2: -0.0108
# ------------------------------------------------------------------------------------------
# 162. Grado Polinómico: 2, Combinación: region_southeast, region_southwest, children, sex
#    Máximo EA: 45961.18
#    EA Medio: 9132.03
#    R^2: -0.0001
# ------------------------------------------------------------------------------------------
# 163. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_northwest, region_southeast
#    Máximo EA: 44360.37
#    EA Medio: 9357.66
#    R^2: 0.0570
# ------------------------------------------------------------------------------------------
# 164. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_northwest, region_southwest
#    Máximo EA: 44360.37
#    EA Medio: 9357.66
#    R^2: 0.0570
# ------------------------------------------------------------------------------------------
# 165. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_northwest, children
#    Máximo EA: 44102.10
#    EA Medio: 9320.97
#    R^2: 0.0717
# ------------------------------------------------------------------------------------------
# 166. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_northwest, sex
#    Máximo EA: 46054.27
#    EA Medio: 9371.29
#    R^2: 0.0614
# ------------------------------------------------------------------------------------------
# 167. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_southeast, region_southwest
#    Máximo EA: 44360.37
#    EA Medio: 9357.66
#    R^2: 0.0570
# ------------------------------------------------------------------------------------------
# 168. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_southeast, children
#    Máximo EA: 44186.93
#    EA Medio: 9336.37
#    R^2: 0.0576
# ------------------------------------------------------------------------------------------
# 169. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_southeast, sex
#    Máximo EA: 46051.20
#    EA Medio: 9388.59
#    R^2: 0.0458
# ------------------------------------------------------------------------------------------
# 170. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_southwest, children
#    Máximo EA: 44179.60
#    EA Medio: 9328.53
#    R^2: 0.0619
# ------------------------------------------------------------------------------------------
# 171. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, region_southwest, sex
#    Máximo EA: 46209.23
#    EA Medio: 9361.00
#    R^2: 0.0545
# ------------------------------------------------------------------------------------------
# 172. Grado Polinómico: 2, Combinación: age, bmi, region_northeast, children, sex
#    Máximo EA: 45880.92
#    EA Medio: 9324.00
#    R^2: 0.0661
# ------------------------------------------------------------------------------------------
# 173. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, region_southeast, region_southwest
#    Máximo EA: 44360.37
#    EA Medio: 9357.66
#    R^2: 0.0570
# ------------------------------------------------------------------------------------------
# 174. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, region_southeast, children
#    Máximo EA: 46053.17
#    EA Medio: 9238.54
#    R^2: 0.0722
# ------------------------------------------------------------------------------------------
# 175. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, region_southeast, sex
#    Máximo EA: 47460.40
#    EA Medio: 9298.17
#    R^2: 0.0601
# ------------------------------------------------------------------------------------------
# 176. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, region_southwest, children
#    Máximo EA: 44629.65
#    EA Medio: 9310.58
#    R^2: 0.0583
# ------------------------------------------------------------------------------------------
# 177. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, region_southwest, sex
#    Máximo EA: 46577.33
#    EA Medio: 9361.43
#    R^2: 0.0491
# ------------------------------------------------------------------------------------------
# 178. Grado Polinómico: 2, Combinación: age, bmi, region_northwest, children, sex
#    Máximo EA: 46863.69
#    EA Medio: 9227.93
#    R^2: 0.0767
# ------------------------------------------------------------------------------------------
# 179. Grado Polinómico: 2, Combinación: age, bmi, region_southeast, region_southwest, children
#    Máximo EA: 45696.00
#    EA Medio: 9283.80
#    R^2: 0.0612
# ------------------------------------------------------------------------------------------
# 180. Grado Polinómico: 2, Combinación: age, bmi, region_southeast, region_southwest, sex
#    Máximo EA: 46714.25
#    EA Medio: 9319.40
#    R^2: 0.0544
# ------------------------------------------------------------------------------------------
# 181. Grado Polinómico: 2, Combinación: age, bmi, region_southeast, children, sex
#    Máximo EA: 47317.45
#    EA Medio: 9228.21
#    R^2: 0.0670
# ------------------------------------------------------------------------------------------
# 182. Grado Polinómico: 2, Combinación: age, bmi, region_southwest, children, sex
#    Máximo EA: 46550.91
#    EA Medio: 9278.27
#    R^2: 0.0615
# ------------------------------------------------------------------------------------------
# 183. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, region_southeast, region_southwest
#    Máximo EA: 47748.74
#    EA Medio: 9401.31
#    R^2: 0.0209
# ------------------------------------------------------------------------------------------
# 184. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, region_southeast, children
#    Máximo EA: 47640.80
#    EA Medio: 9341.76
#    R^2: 0.0278
# ------------------------------------------------------------------------------------------
# 185. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, region_southeast, sex
#    Máximo EA: 48664.99
#    EA Medio: 9406.16
#    R^2: 0.0126
# ------------------------------------------------------------------------------------------
# 186. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, region_southwest, children
#    Máximo EA: 47640.80
#    EA Medio: 9341.76
#    R^2: 0.0278
# ------------------------------------------------------------------------------------------
# 187. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, region_southwest, sex
#    Máximo EA: 48664.99
#    EA Medio: 9406.16
#    R^2: 0.0126
# ------------------------------------------------------------------------------------------
# 188. Grado Polinómico: 2, Combinación: age, region_northeast, region_northwest, children, sex
#    Máximo EA: 48512.24
#    EA Medio: 9385.74
#    R^2: 0.0270
# ------------------------------------------------------------------------------------------
# 189. Grado Polinómico: 2, Combinación: age, region_northeast, region_southeast, region_southwest, children
#    Máximo EA: 47640.80
#    EA Medio: 9341.76
#    R^2: 0.0278
# ------------------------------------------------------------------------------------------
# 190. Grado Polinómico: 2, Combinación: age, region_northeast, region_southeast, region_southwest, sex
#    Máximo EA: 48664.99
#    EA Medio: 9406.16
#    R^2: 0.0126
# ------------------------------------------------------------------------------------------
# 191. Grado Polinómico: 2, Combinación: age, region_northeast, region_southeast, children, sex
#    Máximo EA: 48510.76
#    EA Medio: 9368.74
#    R^2: 0.0118
# ------------------------------------------------------------------------------------------
# 192. Grado Polinómico: 2, Combinación: age, region_northeast, region_southwest, children, sex
#    Máximo EA: 48522.14
#    EA Medio: 9383.21
#    R^2: 0.0218
# ------------------------------------------------------------------------------------------
# 193. Grado Polinómico: 2, Combinación: age, region_northwest, region_southeast, region_southwest, children
#    Máximo EA: 47640.80
#    EA Medio: 9341.76
#    R^2: 0.0278
# ------------------------------------------------------------------------------------------
# 194. Grado Polinómico: 2, Combinación: age, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 48664.99
#    EA Medio: 9406.16
#    R^2: 0.0126
# ------------------------------------------------------------------------------------------
# 195. Grado Polinómico: 2, Combinación: age, region_northwest, region_southeast, children, sex
#    Máximo EA: 48790.02
#    EA Medio: 9291.41
#    R^2: 0.0291
# ------------------------------------------------------------------------------------------
# 196. Grado Polinómico: 2, Combinación: age, region_northwest, region_southwest, children, sex
#    Máximo EA: 48107.73
#    EA Medio: 9356.27
#    R^2: 0.0189
# ------------------------------------------------------------------------------------------
# 197. Grado Polinómico: 2, Combinación: age, region_southeast, region_southwest, children, sex
#    Máximo EA: 48571.44
#    EA Medio: 9318.05
#    R^2: 0.0247
# ------------------------------------------------------------------------------------------
# 198. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, region_southeast, region_southwest
#    Máximo EA: 46158.17
#    EA Medio: 9093.58
#    R^2: 0.0436
# ------------------------------------------------------------------------------------------
# 199. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, region_southeast, children
#    Máximo EA: 43832.47
#    EA Medio: 9155.30
#    R^2: 0.0422
# ------------------------------------------------------------------------------------------
# 200. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, region_southeast, sex
#    Máximo EA: 45724.80
#    EA Medio: 9156.00
#    R^2: 0.0314
# ------------------------------------------------------------------------------------------
# 201. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, region_southwest, children
#    Máximo EA: 43832.47
#    EA Medio: 9155.30
#    R^2: 0.0422
# ------------------------------------------------------------------------------------------
# 202. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, region_southwest, sex
#    Máximo EA: 45724.80
#    EA Medio: 9156.00
#    R^2: 0.0314
# ------------------------------------------------------------------------------------------
# 203. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_northwest, children, sex
#    Máximo EA: 43361.26
#    EA Medio: 9215.53
#    R^2: 0.0441
# ------------------------------------------------------------------------------------------
# 204. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southeast, region_southwest, children
#    Máximo EA: 43832.47
#    EA Medio: 9155.30
#    R^2: 0.0422
# ------------------------------------------------------------------------------------------
# 205. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southeast, region_southwest, sex
#    Máximo EA: 45724.80
#    EA Medio: 9156.00
#    R^2: 0.0314
# ------------------------------------------------------------------------------------------
# 206. Grado Polinómico: 2, Combinación: bmi, region_northeast, region_southeast, children, sex
#    Máximo EA: 44236.78
#    EA Medio: 9224.96
#    R^2: 0.0302
# ------------------------------------------------------------------------------------------
# ...
# 705. Grado Polinómico: 6, Combinación: age, region_northwest, region_southeast, children, sex
#    Máximo EA: 138341.46
#    EA Medio: 10178.02
#    R^2: -0.5634
# ------------------------------------------------------------------------------------------
# 706. Grado Polinómico: 6, Combinación: age, region_northwest, region_southwest, children, sex
#    Máximo EA: 121329.49
#    EA Medio: 10149.26
#    R^2: -0.5555
# ------------------------------------------------------------------------------------------
# 707. Grado Polinómico: 6, Combinación: age, region_southeast, region_southwest, children, sex
#    Máximo EA: 89187.94
#    EA Medio: 10459.19
#    R^2: -0.5191
# ------------------------------------------------------------------------------------------
# 708. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southeast, region_southwest
#    Máximo EA: 47757.86
#    EA Medio: 9155.29
#    R^2: 0.0201
# ------------------------------------------------------------------------------------------
# 709. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southeast, children
#    Máximo EA: 246588.15
#    EA Medio: 10320.88
#    R^2: -1.5333
# ------------------------------------------------------------------------------------------
# 710. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southeast, sex
#    Máximo EA: 46623.22
#    EA Medio: 9524.05
#    R^2: -0.0318
# ------------------------------------------------------------------------------------------
# 711. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southwest, children
#    Máximo EA: 246581.86
#    EA Medio: 10320.80
#    R^2: -1.5333
# ------------------------------------------------------------------------------------------
# 712. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southwest, sex
#    Máximo EA: 46502.08
#    EA Medio: 9385.91
#    R^2: -0.0151
# ------------------------------------------------------------------------------------------
# 713. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, children, sex
#    Máximo EA: 216003.26
#    EA Medio: 10353.03
#    R^2: -1.2686
# ------------------------------------------------------------------------------------------
# 714. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_southeast, region_southwest, children
#    Máximo EA: 246578.06
#    EA Medio: 10320.77
#    R^2: -1.5331
# ------------------------------------------------------------------------------------------
# 715. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_southeast, region_southwest, sex
#    Máximo EA: 46611.83
#    EA Medio: 9535.44
#    R^2: -0.0379
# ------------------------------------------------------------------------------------------
# 716. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_southeast, children, sex
#    Máximo EA: 136040.77
#    EA Medio: 10413.52
#    R^2: -0.5729
# ------------------------------------------------------------------------------------------
# 717. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_southwest, children, sex
#    Máximo EA: 334608.67
#    EA Medio: 12154.34
#    R^2: -4.5909
# ------------------------------------------------------------------------------------------
# 718. Grado Polinómico: 6, Combinación: bmi, region_northwest, region_southeast, region_southwest, children
#    Máximo EA: 435035.12
#    EA Medio: 14997.13
#    R^2: -8.1958
# ------------------------------------------------------------------------------------------
# 719. Grado Polinómico: 6, Combinación: bmi, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 45457.76
#    EA Medio: 9354.19
#    R^2: -0.0026
# ------------------------------------------------------------------------------------------
# 720. Grado Polinómico: 6, Combinación: bmi, region_northwest, region_southeast, children, sex
#    Máximo EA: 299314.99
#    EA Medio: 11467.78
#    R^2: -2.8297
# ------------------------------------------------------------------------------------------
# 721. Grado Polinómico: 6, Combinación: bmi, region_northwest, region_southwest, children, sex
#    Máximo EA: 356010.41
#    EA Medio: 11639.76
#    R^2: -3.9756
# ------------------------------------------------------------------------------------------
# 722. Grado Polinómico: 6, Combinación: bmi, region_southeast, region_southwest, children, sex
#    Máximo EA: 385080.38
#    EA Medio: 12277.44
#    R^2: -4.9135
# ------------------------------------------------------------------------------------------
# 723. Grado Polinómico: 6, Combinación: region_northeast, region_northwest, region_southeast, region_southwest, children
#    Máximo EA: 44836.50
#    EA Medio: 8971.06
#    R^2: 0.0298
# ------------------------------------------------------------------------------------------
# 724. Grado Polinómico: 6, Combinación: region_northeast, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 48892.40
#    EA Medio: 9197.57
#    R^2: -0.0234
# ------------------------------------------------------------------------------------------
# 725. Grado Polinómico: 6, Combinación: region_northeast, region_northwest, region_southeast, children, sex
#    Máximo EA: 44201.27
#    EA Medio: 8987.12
#    R^2: 0.0375
# ------------------------------------------------------------------------------------------
# 726. Grado Polinómico: 6, Combinación: region_northeast, region_northwest, region_southwest, children, sex
#    Máximo EA: 42717.70
#    EA Medio: 9065.64
#    R^2: 0.0310
# ------------------------------------------------------------------------------------------
# 727. Grado Polinómico: 6, Combinación: region_northeast, region_southeast, region_southwest, children, sex
#    Máximo EA: 47078.49
#    EA Medio: 9129.80
#    R^2: -0.0013
# ------------------------------------------------------------------------------------------
# 728. Grado Polinómico: 6, Combinación: region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 44239.30
#    EA Medio: 8987.58
#    R^2: 0.0379
# ------------------------------------------------------------------------------------------
# 729. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southeast, region_southwest
#    Máximo EA: 56847.58
#    EA Medio: 9759.81
#    R^2: -0.1056
# ------------------------------------------------------------------------------------------
# 730. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southeast, children
#    Máximo EA: 860606.42
#    EA Medio: 15948.17
#    R^2: -20.1801
# ------------------------------------------------------------------------------------------
# 731. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southeast, sex
#    Máximo EA: 49790.48
#    EA Medio: 9798.42
#    R^2: -0.0914
# ------------------------------------------------------------------------------------------
# 732. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southwest, children
#    Máximo EA: 859969.77
#    EA Medio: 15890.30
#    R^2: -20.0567
# ------------------------------------------------------------------------------------------
# 733. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southwest, sex
#    Máximo EA: 49249.38
#    EA Medio: 9823.70
#    R^2: -0.0985
# ------------------------------------------------------------------------------------------
# 734. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, children, sex
#    Máximo EA: 557176.82
#    EA Medio: 17982.41
#    R^2: -17.7546
# ------------------------------------------------------------------------------------------
# 735. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_southeast, region_southwest, children
#    Máximo EA: 869100.21
#    EA Medio: 15846.39
#    R^2: -20.2287
# ------------------------------------------------------------------------------------------
# 736. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_southeast, region_southwest, sex
#    Máximo EA: 46663.77
#    EA Medio: 10009.58
#    R^2: -0.1338
# ------------------------------------------------------------------------------------------
# 737. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_southeast, children, sex
#    Máximo EA: 414229.46
#    EA Medio: 17889.93
#    R^2: -13.0172
# ------------------------------------------------------------------------------------------
# 738. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_southwest, children, sex
#    Máximo EA: 523710.54
#    EA Medio: 18964.15
#    R^2: -18.2347
# ------------------------------------------------------------------------------------------
# 739. Grado Polinómico: 6, Combinación: age, bmi, region_northwest, region_southeast, region_southwest, children
#    Máximo EA: 818111.43
#    EA Medio: 15753.48
#    R^2: -17.4825
# ------------------------------------------------------------------------------------------
# 740. Grado Polinómico: 6, Combinación: age, bmi, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 49825.75
#    EA Medio: 9754.52
#    R^2: -0.0937
# ------------------------------------------------------------------------------------------
# 741. Grado Polinómico: 6, Combinación: age, bmi, region_northwest, region_southeast, children, sex
#    Máximo EA: 545291.90
#    EA Medio: 15396.94
#    R^2: -12.4872
# ------------------------------------------------------------------------------------------
# 742. Grado Polinómico: 6, Combinación: age, bmi, region_northwest, region_southwest, children, sex
#    Máximo EA: 509709.56
#    EA Medio: 16832.37
#    R^2: -14.8154
# ------------------------------------------------------------------------------------------
# 743. Grado Polinómico: 6, Combinación: age, bmi, region_southeast, region_southwest, children, sex
#    Máximo EA: 781364.35
#    EA Medio: 17051.93
#    R^2: -18.0128
# ------------------------------------------------------------------------------------------
# 744. Grado Polinómico: 6, Combinación: age, region_northeast, region_northwest, region_southeast, region_southwest, children
#    Máximo EA: 66155.97
#    EA Medio: 9646.10
#    R^2: -0.1332
# ------------------------------------------------------------------------------------------
# 745. Grado Polinómico: 6, Combinación: age, region_northeast, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 45160.46
#    EA Medio: 9334.98
#    R^2: -0.0079
# ------------------------------------------------------------------------------------------
# 746. Grado Polinómico: 6, Combinación: age, region_northeast, region_northwest, region_southeast, children, sex
#    Máximo EA: 136252.50
#    EA Medio: 10418.90
#    R^2: -0.6616
# ------------------------------------------------------------------------------------------
# 747. Grado Polinómico: 6, Combinación: age, region_northeast, region_northwest, region_southwest, children, sex
#    Máximo EA: 136341.41
#    EA Medio: 10423.34
#    R^2: -0.6615
# ------------------------------------------------------------------------------------------
# 748. Grado Polinómico: 6, Combinación: age, region_northeast, region_southeast, region_southwest, children, sex
#    Máximo EA: 136349.08
#    EA Medio: 10424.23
#    R^2: -0.6615
# ------------------------------------------------------------------------------------------
# 749. Grado Polinómico: 6, Combinación: age, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 135921.81
#    EA Medio: 10419.74
#    R^2: -0.6568
# ------------------------------------------------------------------------------------------
# 750. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southeast, region_southwest, children
#    Máximo EA: 240080.02
#    EA Medio: 10244.86
#    R^2: -1.4050
# ------------------------------------------------------------------------------------------
# 751. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 46694.45
#    EA Medio: 9512.24
#    R^2: -0.0388
# ------------------------------------------------------------------------------------------
# 752. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southeast, children, sex
#    Máximo EA: 386208.29
#    EA Medio: 13223.29
#    R^2: -7.5555
# ------------------------------------------------------------------------------------------
# 753. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southwest, children, sex
#    Máximo EA: 386162.67
#    EA Medio: 13222.94
#    R^2: -7.5543
# ------------------------------------------------------------------------------------------
# 754. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_southeast, region_southwest, children, sex
#    Máximo EA: 386207.00
#    EA Medio: 13223.51
#    R^2: -7.5559
# ------------------------------------------------------------------------------------------
# 755. Grado Polinómico: 6, Combinación: bmi, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 386173.36
#    EA Medio: 13223.25
#    R^2: -7.5546
# ------------------------------------------------------------------------------------------
# 756. Grado Polinómico: 6, Combinación: region_northeast, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 44207.72
#    EA Medio: 8989.48
#    R^2: 0.0386
# ------------------------------------------------------------------------------------------
# 757. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southeast, region_southwest, children
#    Máximo EA: 871189.00
#    EA Medio: 15817.27
#    R^2: -20.2491
# ------------------------------------------------------------------------------------------
# 758. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southeast, region_southwest, sex
#    Máximo EA: 48494.04
#    EA Medio: 10068.47
#    R^2: -0.1609
# ------------------------------------------------------------------------------------------
# 759. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southeast, children, sex
#    Máximo EA: 805397.17
#    EA Medio: 23524.26
#    R^2: -38.6482
# ------------------------------------------------------------------------------------------
# 760. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southwest, children, sex
#    Máximo EA: 632091.18
#    EA Medio: 23267.52
#    R^2: -31.8414
# ------------------------------------------------------------------------------------------
# 761. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_southeast, region_southwest, children, sex
#    Máximo EA: 900620.21
#    EA Medio: 24585.99
#    R^2: -45.7885
# ------------------------------------------------------------------------------------------
# 762. Grado Polinómico: 6, Combinación: age, bmi, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 783867.94
#    EA Medio: 24398.95
#    R^2: -39.9654
# ------------------------------------------------------------------------------------------
# 763. Grado Polinómico: 6, Combinación: age, region_northeast, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 133362.50
#    EA Medio: 10380.88
#    R^2: -0.6421
# ------------------------------------------------------------------------------------------
# 764. Grado Polinómico: 6, Combinación: bmi, region_northeast, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 396354.29
#    EA Medio: 13170.64
#    R^2: -7.1300
# ------------------------------------------------------------------------------------------
# 765. Grado Polinómico: 6, Combinación: age, bmi, region_northeast, region_northwest, region_southeast, region_southwest, children, sex
#    Máximo EA: 840163.75
#    EA Medio: 23724.30
#    R^2: -42.0361
# ------------------------------------------------------------------------------------------
